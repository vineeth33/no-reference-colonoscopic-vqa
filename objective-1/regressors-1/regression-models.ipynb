# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import os
import pickle
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.neural_network import MLPRegressor
from scipy.stats import pearsonr, spearmanr, kendalltau
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
class RegressionModelTrainer:
    """
    A comprehensive class for training multiple regression models on scaled feature datasets
    with hyperparameter tuning and performance evaluation.
    """
    
    def __init__(self, features_base_path, labels_path, models_save_path):
        """
        Initialize the trainer with paths and configuration.
        
        Args:
            features_base_path: Base path to scaled features directory
            labels_path: Path to the labels CSV file
            models_save_path: Base path to save trained models
        """
        self.features_base_path = features_base_path
        self.labels_path = labels_path
        self.models_save_path = models_save_path
        
        # Define scaling methods and dataset types
        self.scaling_methods = ['log', 'log1p', 'minmax', 'power', 'quantile', 'robust', 'standard']
        self.dataset_types = ['all_features', 'by_component', 's_only']
        self.labels = ['TSV', 'B', 'SR', 'S', 'U', 'O']
        
        # Define models and their hyperparameter grids
        self.models = {
            'linear_regression': {
                'model': LinearRegression,
                'params': {}  # Linear regression has no hyperparameters to tune
            },
            'svr': {
                'model': SVR,
                'params': {
                    'C': [0.1, 1, 10, 100],
                    'gamma': ['scale', 'auto', 0.001, 0.01, 0.1, 1],
                    'kernel': ['rbf', 'poly', 'sigmoid'],
                    'epsilon': [0.01, 0.1, 0.2]
                }
            },
            'random_forest': {
                'model': RandomForestRegressor,
                'params': {
                    'n_estimators': [50, 100, 200, 300],
                    'max_depth': [None, 10, 20, 30],
                    'min_samples_split': [2, 5, 10],
                    'min_samples_leaf': [1, 2, 4],
                    'max_features': ['auto', 'sqrt', 'log2']
                }
            },
            'gbm': {
                'model': GradientBoostingRegressor,
                'params': {
                    'n_estimators': [50, 100, 200],
                    'learning_rate': [0.01, 0.1, 0.2],
                    'max_depth': [3, 5, 7],
                    'min_samples_split': [2, 5, 10],
                    'min_samples_leaf': [1, 2, 4],
                    'subsample': [0.8, 0.9, 1.0]
                }
            }
        }
        
        # Create directories for saving models
        self._create_model_directories()
        
        # Load labels
        self.labels_df = self._load_labels()
        
        # Initialize results storage
        self.results = []
    
    def _create_model_directories(self):
        """Create directories for saving trained models."""
        for model_name in self.models.keys():
            model_dir = os.path.join(self.models_save_path, model_name)
            os.makedirs(model_dir, exist_ok=True)
    
    def _load_labels(self):
        """Load the labels CSV file."""
        try:
            labels_df = pd.read_csv(self.labels_path)
            print(f"Labels loaded successfully. Shape: {labels_df.shape}\n\n")
            return labels_df
        except Exception as e:
            print(f"Error loading labels: {e}\n\n")
            return None
    
    def _load_features(self, scaling_method, dataset_type):
        """
        Load features for a specific scaling method and dataset type.
        
        Args:
            scaling_method: The scaling method (e.g., 'log', 'minmax')
            dataset_type: The dataset type (e.g., 'all_features', 'by_component')
        
        Returns:
            pandas.DataFrame: Loaded features
        """
        filename = f"{dataset_type}_{scaling_method}.csv"
        filepath = os.path.join(self.features_base_path, scaling_method, filename)
        
        try:
            features_df = pd.read_csv(filepath)
            features_df = features_df.drop('videoname', axis=1)
            print(f"Features loaded: {filename}, Shape: {features_df.shape}\n\n")
            return features_df
        except Exception as e:
            print(f"Error loading {filename}: {e}\n\n")
            return None
    
    def _calculate_metrics(self, y_true, y_pred):
        """
        Calculate evaluation metrics: PLCC, SRCC, KRCC, RMSE.
        
        Args:
            y_true: True values
            y_pred: Predicted values
            
        Returns:
            dict: Dictionary containing all metrics
        """
        # Remove NaN values
        mask = ~(np.isnan(y_true) | np.isnan(y_pred))
        y_true_clean = y_true[mask]
        y_pred_clean = y_pred[mask]
        
        if len(y_true_clean) == 0:
            return {'PLCC': np.nan, 'SRCC': np.nan, 'KRCC': np.nan, 'RMSE': np.nan}
        
        # PLCC (Pearson Linear Correlation Coefficient)
        plcc, _ = pearsonr(y_true_clean, y_pred_clean)
        
        # SRCC (Spearman Rank Correlation Coefficient)
        srcc, _ = spearmanr(y_true_clean, y_pred_clean)
        
        # KRCC (Kendall Rank Correlation Coefficient)
        krcc, _ = kendalltau(y_true_clean, y_pred_clean)
        
        # RMSE (Root Mean Square Error)
        rmse = np.sqrt(mean_squared_error(y_true_clean, y_pred_clean))
        
        return {
            'PLCC': plcc,
            'SRCC': srcc,
            'KRCC': krcc,
            'RMSE': rmse
        }
    
    def _train_model(self, model_name, X_train, y_train, X_test, y_test):
        """
        Train a single model with hyperparameter tuning.
        
        Args:
            model_name: Name of the model to train
            X_train, y_train: Training data
            X_test, y_test: Testing data
            
        Returns:
            tuple: (trained_model, metrics_dict)
        """
        model_config = self.models[model_name]
        model_class = model_config['model']
        param_grid = model_config['params']
        
        print(f"    Training {model_name}...")
        
        if model_name == 'linear_regression':
            # No hyperparameter tuning needed for linear regression
            model = model_class()
            model.fit(X_train, y_train)
            best_model = model
        else:
            # Use RandomizedSearchCV for faster hyperparameter tuning
            if model_name == 'svr':
                model = model_class()
            else:
                model = model_class(random_state=42)
            
            # Adjust search strategy based on model complexity
            if model_name in ['svr', 'gbm']:
                search_cv = RandomizedSearchCV(
                    model, param_grid, n_iter=20, cv=3, 
                    scoring='neg_mean_squared_error', random_state=42, n_jobs=-1
                )
            else:
                search_cv = RandomizedSearchCV(
                    model, param_grid, n_iter=30, cv=3,
                    scoring='neg_mean_squared_error', random_state=42, n_jobs=-1
                )
            
            search_cv.fit(X_train, y_train)
            best_model = search_cv.best_estimator_
            print(f"      Best parameters: {search_cv.best_params_}")
        print("\n")
        # Make predictions
        y_pred = best_model.predict(X_test)
        
        # Calculate metrics
        metrics = self._calculate_metrics(y_test, y_pred)
        
        return best_model, metrics
    
    def _save_model(self, model, model_name, dataset_name, label_name):
        """
        Save a trained model to disk.
        
        Args:
            model: Trained model object
            model_name: Name of the model type
            dataset_name: Name of the dataset
            label_name: Name of the target label
        """
        model_dir = os.path.join(self.models_save_path, model_name)
        filename = f"{dataset_name}_{label_name}.pkl"
        filepath = os.path.join(model_dir, filename)
        
        try:
            with open(filepath, 'wb') as f:
                pickle.dump(model, f)
            print(f"      Model saved: {filepath}")
        except Exception as e:
            print(f"      Error saving model {filepath}: {e}")
        print("\n")
    
    def train_all_models(self, test_size=0.2, random_state=42):
        """
        Train all models on all datasets for all labels.
        
        Args:
            test_size: Proportion of data to use for testing
            random_state: Random seed for reproducibility
        """
        print("Starting comprehensive model training...")
        print(f"Total combinations: {len(self.scaling_methods)} scaling methods × "
              f"{len(self.dataset_types)} dataset types × {len(self.labels)} labels × "
              f"{len(self.models)} models = {len(self.scaling_methods) * len(self.dataset_types) * len(self.labels) * len(self.models)} models")
        
        total_models = 0
        successful_models = 0
        
        for scaling_method in self.scaling_methods:
            for dataset_type in self.dataset_types:
                dataset_name = f"{dataset_type}_{scaling_method}"
                print(f"\nProcessing dataset: {dataset_name}")
                
                # Load features
                features_df = self._load_features(scaling_method, dataset_type)
                if features_df is None:
                    print(f"  Skipping {dataset_name} due to loading error")
                    continue
                
                for label in self.labels:
                    print(f"  Target label: {label}")
                    
                    # Check if label exists in labels dataframe
                    if label not in self.labels_df.columns:
                        print(f"    Label {label} not found in labels file")
                        continue
                    
                    # Prepare data
                    y = self.labels_df[label].values
                    X = features_df.values
                    
                    # Check for matching dimensions
                    if len(X) != len(y):
                        print(f"    Dimension mismatch: Features={len(X)}, Labels={len(y)}")
                        continue
                    
                    # Remove samples with NaN values
                    mask = ~(np.isnan(y) | np.isnan(X).any(axis=1))
                    X_clean = X[mask]
                    y_clean = y[mask]
                    
                    if len(X_clean) == 0:
                        print(f"    No valid samples after cleaning")
                        continue
                    
                    # Split data
                    X_train, X_test, y_train, y_test = train_test_split(
                        X_clean, y_clean, test_size=test_size, random_state=random_state
                    )
                    
                    # Train each model
                    for model_name in self.models.keys():
                        total_models += 1
                        
                        try:
                            model, metrics = self._train_model(
                                model_name, X_train, y_train, X_test, y_test
                            )
                            
                            # Save model
                            self._save_model(model, model_name, dataset_name, label)
                            
                            # Store results
                            result = {
                                'scaling_method': scaling_method,
                                'dataset_type': dataset_type,
                                'dataset_name': dataset_name,
                                'label': label,
                                'model': model_name,
                                'train_samples': len(X_train),
                                'test_samples': len(X_test),
                                **metrics
                            }
                            self.results.append(result)
                            
                            successful_models += 1
                            
                            print(f"      ✓ {model_name} - PLCC: {metrics['PLCC']:.4f}, "
                                  f"SRCC: {metrics['SRCC']:.4f}, KRCC: {metrics['KRCC']:.4f}, "
                                  f"RMSE: {metrics['RMSE']:.4f}")
                            
                        except Exception as e:
                            print(f"      ✗ {model_name} failed: {e}")
        
        print(f"\nTraining completed!")
        print(f"Successfully trained: {successful_models}/{total_models} models\n\n")
        
        # Save results to CSV
        self.save_results()
    
    def save_results(self, filename="training_results.csv"):
        """Save all training results to a CSV file."""
        if self.results:
            results_df = pd.DataFrame(self.results)
            filepath = os.path.join(self.models_save_path, filename)
            results_df.to_csv(filepath, index=False)
            print(f"\nResults saved to: {filepath}")
            
            # Display summary statistics
            self.display_results_summary(results_df)
        else:
            print("No results to save.")

        print("\n")
    
    def display_results_summary(self, results_df):
        """Display summary statistics of the training results."""
        print("\n" + "="*80)
        print("TRAINING RESULTS SUMMARY")
        print("="*80)
        
        # Best models by metric
        metrics = ['PLCC', 'SRCC', 'KRCC', 'RMSE']
        
        for metric in metrics:
            print(f"\nBest {metric}:")
            if metric == 'RMSE':
                best_result = results_df.loc[results_df[metric].idxmin()]
                print(f"  {best_result['model']} on {best_result['dataset_name']} "
                      f"for {best_result['label']}: {best_result[metric]:.4f}")
            else:
                best_result = results_df.loc[results_df[metric].idxmax()]
                print(f"  {best_result['model']} on {best_result['dataset_name']} "
                      f"for {best_result['label']}: {best_result[metric]:.4f}")
        
        # Average performance by model
        print(f"\nAverage Performance by Model:")
        model_avg = results_df.groupby('model')[metrics].mean()
        for model in model_avg.index:
            print(f"  {model}:")
            for metric in metrics:
                print(f"    {metric}: {model_avg.loc[model, metric]:.4f}")
        
        # Average performance by dataset
        print(f"\nTop 5 Dataset Configurations (by PLCC):")
        dataset_avg = results_df.groupby(['dataset_name', 'label'])['PLCC'].mean().sort_values(ascending=False).head()
        for (dataset, label), plcc in dataset_avg.items():
            print(f"  {dataset} → {label}: {plcc:.4f}")
        print("\n")

# %%
class RegressionModelTrainer:
    """
    A comprehensive class for training multiple regression models on scaled feature datasets
    with hyperparameter tuning and performance evaluation.
    """
    
    def __init__(self, features_base_path, labels_path, models_save_path):
        """
        Initialize the trainer with paths and configuration.
        
        Args:
            features_base_path: Base path to scaled features directory
            labels_path: Path to the labels CSV file
            models_save_path: Base path to save trained models
        """
        self.features_base_path = features_base_path
        self.labels_path = labels_path
        self.models_save_path = models_save_path
        
        # Define scaling methods and dataset types
        self.scaling_methods = ['log', 'log1p', 'minmax', 'power', 'quantile', 'robust', 'standard']
        self.dataset_types = ['all_features', 'by_component', 's_only']
        self.labels = ['TSV', 'B', 'SR', 'S', 'U', 'O']
        
        # Define models and their hyperparameter grids
        self.models = {
            'linear_regression': {
                'model': LinearRegression,
                'params': {}  # Linear regression has no hyperparameters to tune
            },
            'ridge_regression': {
                'model': Ridge,
                'params': {
                    'alpha': [0.01, 0.1, 1, 10, 100, 1000],
                    'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga'],
                    'max_iter': [1000, 2000, 3000]
                }
            },
            'svr': {
                'model': SVR,
                'params': {
                    'C': [0.1, 1, 10, 100],
                    'gamma': ['scale', 'auto', 0.001, 0.01, 0.1, 1],
                    'kernel': ['rbf', 'poly', 'sigmoid'],
                    'epsilon': [0.01, 0.1, 0.2]
                }
            },
            'random_forest': {
                'model': RandomForestRegressor,
                'params': {
                    'n_estimators': [50, 100, 200, 300],
                    'max_depth': [None, 10, 20, 30],
                    'min_samples_split': [2, 5, 10],
                    'min_samples_leaf': [1, 2, 4],
                    'max_features': ['auto', 'sqrt', 'log2']
                }
            },
            'gbm': {
                'model': GradientBoostingRegressor,
                'params': {
                    'n_estimators': [50, 100, 200],
                    'learning_rate': [0.01, 0.1, 0.2],
                    'max_depth': [3, 5, 7],
                    'min_samples_split': [2, 5, 10],
                    'min_samples_leaf': [1, 2, 4],
                    'subsample': [0.8, 0.9, 1.0]
                }
            },
            'mlp': {
                'model': MLPRegressor,
                'params': {
                    'hidden_layer_sizes': [(50,), (100,), (50, 50), (100, 50), (100, 100), (100, 50, 25)],
                    'activation': ['relu', 'tanh', 'logistic'],
                    'solver': ['adam', 'lbfgs', 'sgd'],
                    'alpha': [0.0001, 0.001, 0.01, 0.1],
                    'learning_rate': ['constant', 'invscaling', 'adaptive'],
                    'max_iter': [500, 1000, 2000]
                }
            }
        }
        
        # Create directories for saving models
        self._create_model_directories()
        
        # Load labels
        self.labels_df = self._load_labels()
        
        # Initialize results storage
        self.results = []
    
    def _create_model_directories(self):
        """Create directories for saving trained models."""
        for model_name in self.models.keys():
            model_dir = os.path.join(self.models_save_path, model_name)
            os.makedirs(model_dir, exist_ok=True)
    
    def _load_labels(self):
        """Load the labels CSV file."""
        try:
            labels_df = pd.read_csv(self.labels_path)
            print(f"Labels loaded successfully. Shape: {labels_df.shape}\n")
            return labels_df
        except Exception as e:
            print(f"Error loading labels: {e}\n")
            return None
    
    def _load_features(self, scaling_method, dataset_type):
        """
        Load features for a specific scaling method and dataset type.
        
        Args:
            scaling_method: The scaling method (e.g., 'log', 'minmax')
            dataset_type: The dataset type (e.g., 'all_features', 'by_component')
        
        Returns:
            pandas.DataFrame: Loaded features
        """
        filename = f"{dataset_type}_{scaling_method}.csv"
        filepath = os.path.join(self.features_base_path, scaling_method, filename)
        
        try:
            features_df = pd.read_csv(filepath)
            features_df = features_df.drop('videoname', axis=1)
            print(f"    Features loaded: {filename}, Shape: {features_df.shape}")
            return features_df
        except Exception as e:
            print(f"    Error loading {filename}: {e}")
            return None
    
    def _model_exists(self, model_name, dataset_name, label_name):
        """
        Check if a trained model already exists.
        
        Args:
            model_name: Name of the model type
            dataset_name: Name of the dataset
            label_name: Name of the target label
            
        Returns:
            bool: True if model file exists, False otherwise
        """
        model_dir = os.path.join(self.models_save_path, model_name)
        filename = f"{dataset_name}_{label_name}.pkl"
        filepath = os.path.join(model_dir, filename)
        return os.path.exists(filepath)
    
    def _load_existing_model(self, model_name, dataset_name, label_name):
        """
        Load an existing trained model from disk.
        
        Args:
            model_name: Name of the model type
            dataset_name: Name of the dataset
            label_name: Name of the target label
            
        Returns:
            model: Loaded model object or None if loading fails
        """
        model_dir = os.path.join(self.models_save_path, model_name)
        filename = f"{dataset_name}_{label_name}.pkl"
        filepath = os.path.join(model_dir, filename)
        
        try:
            with open(filepath, 'rb') as f:
                model = pickle.load(f)
            print(f"      Loaded existing model: {filepath}")
            return model
        except Exception as e:
            print(f"      Error loading existing model {filepath}: {e}")
            return None
    
    def _calculate_metrics(self, y_true, y_pred):
        """
        Calculate evaluation metrics: PLCC, SRCC, KRCC, RMSE.
        
        Args:
            y_true: True values
            y_pred: Predicted values
            
        Returns:
            dict: Dictionary containing all metrics
        """
        # Remove NaN values
        mask = ~(np.isnan(y_true) | np.isnan(y_pred))
        y_true_clean = y_true[mask]
        y_pred_clean = y_pred[mask]
        
        if len(y_true_clean) == 0:
            return {'PLCC': np.nan, 'SRCC': np.nan, 'KRCC': np.nan, 'RMSE': np.nan}
        
        # PLCC (Pearson Linear Correlation Coefficient)
        plcc, _ = pearsonr(y_true_clean, y_pred_clean)
        
        # SRCC (Spearman Rank Correlation Coefficient)
        srcc, _ = spearmanr(y_true_clean, y_pred_clean)
        
        # KRCC (Kendall Rank Correlation Coefficient)
        krcc, _ = kendalltau(y_true_clean, y_pred_clean)
        
        # RMSE (Root Mean Square Error)
        rmse = np.sqrt(mean_squared_error(y_true_clean, y_pred_clean))
        
        return {
            'PLCC': plcc,
            'SRCC': srcc,
            'KRCC': krcc,
            'RMSE': rmse
        }
    
    def _train_model(self, model_name, X_train, y_train, X_test, y_test):
        """
        Train a single model with hyperparameter tuning.
        
        Args:
            model_name: Name of the model to train
            X_train, y_train: Training data
            X_test, y_test: Testing data
            
        Returns:
            tuple: (trained_model, metrics_dict)
        """
        model_config = self.models[model_name]
        model_class = model_config['model']
        param_grid = model_config['params']
        
        print(f"    Training {model_name}...")
        
        if model_name in ['linear_regression']:
            # No hyperparameter tuning needed for simple models
            model = model_class()
            model.fit(X_train, y_train)
            best_model = model
        else:
            # Use RandomizedSearchCV for other models
            if model_name == 'svr':
                model = model_class()
            elif model_name == 'mlp':
                model = model_class(random_state=42, early_stopping=True, validation_fraction=0.1)
            else:
                model = model_class(random_state=42)
            
            # Adjust search strategy based on model complexity
            if model_name in ['svr', 'gbm', 'mlp']:
                search_cv = RandomizedSearchCV(
                    model, param_grid, n_iter=20, cv=3, 
                    scoring='neg_mean_squared_error', random_state=42, n_jobs=-1
                )
            else:
                search_cv = RandomizedSearchCV(
                    model, param_grid, n_iter=30, cv=3,
                    scoring='neg_mean_squared_error', random_state=42, n_jobs=-1
                )
            
            search_cv.fit(X_train, y_train)
            best_model = search_cv.best_estimator_
            print(f"      Best parameters: {search_cv.best_params_}")
        
        # Make predictions
        y_pred = best_model.predict(X_test)
        
        # Calculate metrics
        metrics = self._calculate_metrics(y_test, y_pred)
        
        return best_model, metrics
    
    def _save_model(self, model, model_name, dataset_name, label_name):
        """
        Save a trained model to disk.
        
        Args:
            model: Trained model object
            model_name: Name of the model type
            dataset_name: Name of the dataset
            label_name: Name of the target label
        """
        model_dir = os.path.join(self.models_save_path, model_name)
        filename = f"{dataset_name}_{label_name}.pkl"
        filepath = os.path.join(model_dir, filename)
        
        try:
            with open(filepath, 'wb') as f:
                pickle.dump(model, f)
            print(f"      Model saved: {filepath}")
        except Exception as e:
            print(f"      Error saving model {filepath}: {e}")
    
    def train_all_models(self, test_size=0.2, random_state=42, force_retrain=False):
        """
        Train all models on all datasets for all labels.
        
        Args:
            test_size: Proportion of data to use for testing
            random_state: Random seed for reproducibility
            force_retrain: If True, retrain even if model exists
        """
        print("=" * 80)
        print("STARTING COMPREHENSIVE MODEL TRAINING")
        print("=" * 80)
        print(f"Total combinations: {len(self.scaling_methods)} scaling methods × "
              f"{len(self.dataset_types)} dataset types × {len(self.labels)} labels × "
              f"{len(self.models)} models = {len(self.scaling_methods) * len(self.dataset_types) * len(self.labels) * len(self.models)} models\n")
        
        total_models = 0
        successful_models = 0
        skipped_models = 0
        
        for scaling_method in self.scaling_methods:
            print(f"🔄 Processing scaling method: {scaling_method.upper()}")
            print("-" * 60)
            
            for dataset_type in self.dataset_types:
                dataset_name = f"{dataset_type}_{scaling_method}"
                print(f"\n📊 Dataset: {dataset_name}")
                
                # Load features
                features_df = self._load_features(scaling_method, dataset_type)
                if features_df is None:
                    print(f"    ⚠️  Skipping {dataset_name} due to loading error\n")
                    continue
                
                for label in self.labels:
                    print(f"\n  🎯 Target label: {label}")
                    
                    # Check if label exists in labels dataframe
                    if label not in self.labels_df.columns:
                        print(f"    ❌ Label {label} not found in labels file")
                        continue
                    
                    # Prepare data
                    y = self.labels_df[label].values
                    X = features_df.values
                    
                    # Check for matching dimensions
                    if len(X) != len(y):
                        print(f"    ❌ Dimension mismatch: Features={len(X)}, Labels={len(y)}")
                        continue
                    
                    # Remove samples with NaN values
                    mask = ~(np.isnan(y) | np.isnan(X).any(axis=1))
                    X_clean = X[mask]
                    y_clean = y[mask]
                    
                    if len(X_clean) == 0:
                        print(f"    ❌ No valid samples after cleaning")
                        continue
                    
                    # Split data
                    X_train, X_test, y_train, y_test = train_test_split(
                        X_clean, y_clean, test_size=test_size, random_state=random_state
                    )
                    
                    print(f"    📈 Training samples: {len(X_train)}, Test samples: {len(X_test)}")
                    
                    # Train each model
                    for model_name in self.models.keys():
                        total_models += 1
                        print(f"\n    🤖 Model: {model_name}")
                        
                        # Check if model already exists
                        if not force_retrain and self._model_exists(model_name, dataset_name, label):
                            print(f"      ⏭️  Model already exists, loading...")
                            
                            # Load existing model and evaluate on test set
                            try:
                                existing_model = self._load_existing_model(model_name, dataset_name, label)
                                if existing_model is not None:
                                    # Make predictions with existing model
                                    y_pred = existing_model.predict(X_test)
                                    
                                    # Calculate metrics
                                    metrics = self._calculate_metrics(y_test, y_pred)
                                    
                                    # Store results
                                    result = {
                                        'scaling_method': scaling_method,
                                        'dataset_type': dataset_type,
                                        'dataset_name': dataset_name,
                                        'label': label,
                                        'model': model_name,
                                        'train_samples': len(X_train),
                                        'test_samples': len(X_test),
                                        **metrics
                                    }
                                    self.results.append(result)
                                    
                                    print(f"      ✅ Performance - PLCC: {metrics['PLCC']:.4f}, "
                                          f"SRCC: {metrics['SRCC']:.4f}, KRCC: {metrics['KRCC']:.4f}, "
                                          f"RMSE: {metrics['RMSE']:.4f}")
                                    
                                    successful_models += 1
                                    skipped_models += 1
                                else:
                                    print(f"      ⚠️  Failed to load existing model, will retrain")
                                    # Continue to training section below
                            except Exception as e:
                                print(f"      ⚠️  Error with existing model: {e}, will retrain")
                                # Continue to training section below
                            else:
                                continue  # Skip to next model if existing model was successfully loaded
                        
                        # Train new model
                        try:
                            model, metrics = self._train_model(
                                model_name, X_train, y_train, X_test, y_test
                            )
                            
                            # Save model
                            self._save_model(model, model_name, dataset_name, label)
                            
                            # Store results
                            result = {
                                'scaling_method': scaling_method,
                                'dataset_type': dataset_type,
                                'dataset_name': dataset_name,
                                'label': label,
                                'model': model_name,
                                'train_samples': len(X_train),
                                'test_samples': len(X_test),
                                **metrics
                            }
                            self.results.append(result)
                            
                            successful_models += 1
                            
                            print(f"      ✅ Performance - PLCC: {metrics['PLCC']:.4f}, "
                                  f"SRCC: {metrics['SRCC']:.4f}, KRCC: {metrics['KRCC']:.4f}, "
                                  f"RMSE: {metrics['RMSE']:.4f}")
                            
                        except Exception as e:
                            print(f"      ❌ Training failed: {e}")
            
            print(f"\n{'='*60}")
            print(f"Completed scaling method: {scaling_method.upper()}")
            print(f"{'='*60}\n")
        
        print("=" * 80)
        print("TRAINING COMPLETED!")
        print("=" * 80)
        print(f"✅ Successfully trained/loaded: {successful_models}/{total_models} models")
        print(f"⏭️  Skipped (already existed): {skipped_models}/{total_models} models")
        print(f"🆕 Newly trained: {successful_models - skipped_models}/{total_models} models")
        print("=" * 80)
        
        # Save results to CSV
        self.save_results()
    
    def save_results(self, filename="training_results.csv"):
        """Save all training results to a CSV file."""
        if self.results:
            results_df = pd.DataFrame(self.results)
            filepath = os.path.join(self.models_save_path, filename)
            results_df.to_csv(filepath, index=False)
            print(f"\n📊 Results saved to: {filepath}")
            
            # Display summary statistics
            self.display_results_summary(results_df)
        else:
            print("❌ No results to save.")

        print("\n")
    
    def display_results_summary(self, results_df):
        """Display summary statistics of the training results."""
        print("\n" + "="*80)
        print("🏆 TRAINING RESULTS SUMMARY")
        print("="*80)
        
        # Best models by metric
        metrics = ['PLCC', 'SRCC', 'KRCC', 'RMSE']
        
        print("\n🥇 BEST PERFORMING MODELS BY METRIC:")
        print("-" * 50)
        for metric in metrics:
            if metric == 'RMSE':
                best_result = results_df.loc[results_df[metric].idxmin()]
                print(f"\n  📉 Best {metric} (Lower is better):")
                print(f"     🎯 {best_result['model']} on {best_result['dataset_name']}")
                print(f"     📊 Label: {best_result['label']}")
                print(f"     🎖️  Score: {best_result[metric]:.4f}")
            else:
                best_result = results_df.loc[results_df[metric].idxmax()]
                print(f"\n  📈 Best {metric} (Higher is better):")
                print(f"     🎯 {best_result['model']} on {best_result['dataset_name']}")
                print(f"     📊 Label: {best_result['label']}")
                print(f"     🎖️  Score: {best_result[metric]:.4f}")
        
        # Average performance by model
        print(f"\n\n📊 AVERAGE PERFORMANCE BY MODEL:")
        print("-" * 50)
        model_avg = results_df.groupby('model')[metrics].mean()
        for model in model_avg.index:
            print(f"\n  🤖 {model.upper()}:")
            for metric in metrics:
                print(f"     {metric}: {model_avg.loc[model, metric]:.4f}")
        
        # Average performance by dataset
        print(f"\n\n🏅 TOP 5 DATASET CONFIGURATIONS (by PLCC):")
        print("-" * 50)
        dataset_avg = results_df.groupby(['dataset_name', 'label'])['PLCC'].mean().sort_values(ascending=False).head()
        for i, ((dataset, label), plcc) in enumerate(dataset_avg.items(), 1):
            print(f"  #{i} 📊 {dataset} → {label}: {plcc:.4f}")
        
        print("\n" + "="*80)

# %%
def main():
    # Initialize the trainer
    trainer = RegressionModelTrainer(
        features_base_path="../preprocessing/scaling/scaled-features/",
        labels_path="../../dataset/cleaned/cleaned-mos.csv",
        models_save_path="./"
    )
    
    # Train all models
    trainer.train_all_models(test_size=0.2, random_state=42)
    
    print("\nAll models have been trained and saved!")

if __name__ == "__main__":
    main()
# Out:
# Labels loaded successfully. Shape: (1000, 7)
#
# ================================================================================
# STARTING COMPREHENSIVE MODEL TRAINING
# ================================================================================
# Total combinations: 7 scaling methods × 3 dataset types × 6 labels × 6 models = 756 models
#
# 🔄 Processing scaling method: LOG
# ------------------------------------------------------------
#
# 📊 Dataset: all_features_log
#     Features loaded: all_features_log.csv, Shape: (1000, 1152)
#
#   🎯 Target label: TSV
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\all_features_log_TSV.pkl
#       ✅ Performance - PLCC: 0.5913, SRCC: 0.5889, KRCC: 0.4100, RMSE: 0.7316
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\all_features_log_TSV.pkl
#       ✅ Performance - PLCC: 0.8526, SRCC: 0.8307, KRCC: 0.6476, RMSE: 0.3487
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\all_features_log_TSV.pkl
#       ✅ Performance - PLCC: 0.8502, SRCC: 0.8291, KRCC: 0.6455, RMSE: 0.3511
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\all_features_log_TSV.pkl
#       ✅ Performance - PLCC: 0.7908, SRCC: 0.7597, KRCC: 0.5755, RMSE: 0.4061
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\all_features_log_TSV.pkl
#       ✅ Performance - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\all_features_log_TSV.pkl
#       ✅ Performance - PLCC: 0.8501, SRCC: 0.8276, KRCC: 0.6458, RMSE: 0.3522
#
#   🎯 Target label: B
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\all_features_log_B.pkl
#       ✅ Performance - PLCC: 0.4027, SRCC: 0.4337, KRCC: 0.2991, RMSE: 1.5137
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\all_features_log_B.pkl
#       ✅ Performance - PLCC: 0.7204, SRCC: 0.6889, KRCC: 0.5036, RMSE: 0.5643
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\all_features_log_B.pkl
#       ✅ Performance - PLCC: 0.7245, SRCC: 0.7065, KRCC: 0.5234, RMSE: 0.5607
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\all_features_log_B.pkl
#       ✅ Performance - PLCC: 0.6507, SRCC: 0.6035, KRCC: 0.4349, RMSE: 0.6223
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\all_features_log_B.pkl
#       ✅ Performance - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\all_features_log_B.pkl
#       ✅ Performance - PLCC: 0.7066, SRCC: 0.6896, KRCC: 0.5086, RMSE: 0.5851
#
#   🎯 Target label: SR
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\all_features_log_SR.pkl
#       ✅ Performance - PLCC: 0.2882, SRCC: 0.2967, KRCC: 0.2025, RMSE: 1.1706
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\all_features_log_SR.pkl
#       ✅ Performance - PLCC: 0.7292, SRCC: 0.7393, KRCC: 0.5492, RMSE: 0.4649
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\all_features_log_SR.pkl
#       ✅ Performance - PLCC: 0.7386, SRCC: 0.7499, KRCC: 0.5561, RMSE: 0.4581
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\all_features_log_SR.pkl
#       ✅ Performance - PLCC: 0.6372, SRCC: 0.6237, KRCC: 0.4478, RMSE: 0.5351
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\all_features_log_SR.pkl
#       ✅ Performance - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\all_features_log_SR.pkl
#       ✅ Performance - PLCC: 0.7234, SRCC: 0.7284, KRCC: 0.5389, RMSE: 0.4689
#
#   🎯 Target label: S
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\all_features_log_S.pkl
#       ✅ Performance - PLCC: 0.5414, SRCC: 0.5696, KRCC: 0.3990, RMSE: 0.9704
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\all_features_log_S.pkl
#       ✅ Performance - PLCC: 0.8362, SRCC: 0.8416, KRCC: 0.6461, RMSE: 0.4310
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\all_features_log_S.pkl
#       ✅ Performance - PLCC: 0.8386, SRCC: 0.8414, KRCC: 0.6439, RMSE: 0.4271
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\all_features_log_S.pkl
#       ✅ Performance - PLCC: 0.7742, SRCC: 0.7700, KRCC: 0.5682, RMSE: 0.4959
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\all_features_log_S.pkl
#       ✅ Performance - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\all_features_log_S.pkl
#       ✅ Performance - PLCC: 0.8493, SRCC: 0.8457, KRCC: 0.6491, RMSE: 0.4152
#
#   🎯 Target label: U
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\all_features_log_U.pkl
#       ✅ Performance - PLCC: 0.3960, SRCC: 0.4313, KRCC: 0.3017, RMSE: 1.0575
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\all_features_log_U.pkl
#       ✅ Performance - PLCC: 0.8139, SRCC: 0.8153, KRCC: 0.6170, RMSE: 0.4557
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\all_features_log_U.pkl
#       ✅ Performance - PLCC: 0.8071, SRCC: 0.8114, KRCC: 0.6118, RMSE: 0.4629
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\all_features_log_U.pkl
#       ✅ Performance - PLCC: 0.7401, SRCC: 0.7312, KRCC: 0.5393, RMSE: 0.5288
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\all_features_log_U.pkl
#       ✅ Performance - PLCC: 0.7841, SRCC: 0.7902, KRCC: 0.5926, RMSE: 0.4898
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\all_features_log_U.pkl
#       ✅ Performance - PLCC: 0.7929, SRCC: 0.7910, KRCC: 0.5890, RMSE: 0.4754
#
#   🎯 Target label: O
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\all_features_log_O.pkl
#       ✅ Performance - PLCC: 0.5407, SRCC: 0.5745, KRCC: 0.4128, RMSE: 1.2773
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\all_features_log_O.pkl
#       ✅ Performance - PLCC: 0.8439, SRCC: 0.8408, KRCC: 0.6465, RMSE: 0.5787
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\all_features_log_O.pkl
#       ✅ Performance - PLCC: 0.8405, SRCC: 0.8373, KRCC: 0.6481, RMSE: 0.5852
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\all_features_log_O.pkl
#       ✅ Performance - PLCC: 0.7851, SRCC: 0.7781, KRCC: 0.5878, RMSE: 0.6741
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\all_features_log_O.pkl
#       ✅ Performance - PLCC: 0.8285, SRCC: 0.8201, KRCC: 0.6314, RMSE: 0.6065
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\all_features_log_O.pkl
#       ✅ Performance - PLCC: 0.8277, SRCC: 0.8255, KRCC: 0.6312, RMSE: 0.6056
#
# 📊 Dataset: by_component_log
#     Features loaded: by_component_log.csv, Shape: (1000, 1152)
#
#   🎯 Target label: TSV
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\by_component_log_TSV.pkl
#       ✅ Performance - PLCC: 0.5954, SRCC: 0.6003, KRCC: 0.4193, RMSE: 0.7121
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\by_component_log_TSV.pkl
#       ✅ Performance - PLCC: 0.8537, SRCC: 0.8307, KRCC: 0.6480, RMSE: 0.3468
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\by_component_log_TSV.pkl
#       ✅ Performance - PLCC: 0.8469, SRCC: 0.8265, KRCC: 0.6431, RMSE: 0.3549
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\by_component_log_TSV.pkl
#       ✅ Performance - PLCC: 0.7908, SRCC: 0.7597, KRCC: 0.5755, RMSE: 0.4061
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\by_component_log_TSV.pkl
#       ✅ Performance - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\by_component_log_TSV.pkl
#       ✅ Performance - PLCC: 0.8411, SRCC: 0.8230, KRCC: 0.6378, RMSE: 0.3624
#
#   🎯 Target label: B
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\by_component_log_B.pkl
#       ✅ Performance - PLCC: 0.4206, SRCC: 0.4473, KRCC: 0.3073, RMSE: 1.4011
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\by_component_log_B.pkl
#       ✅ Performance - PLCC: 0.7085, SRCC: 0.6768, KRCC: 0.4944, RMSE: 0.5744
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\by_component_log_B.pkl
#       ✅ Performance - PLCC: 0.7078, SRCC: 0.6926, KRCC: 0.5106, RMSE: 0.5746
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\by_component_log_B.pkl
#       ✅ Performance - PLCC: 0.6507, SRCC: 0.6035, KRCC: 0.4349, RMSE: 0.6223
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\by_component_log_B.pkl
#       ✅ Performance - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\by_component_log_B.pkl
#       ✅ Performance - PLCC: 0.6847, SRCC: 0.6826, KRCC: 0.5002, RMSE: 0.6214
#
#   🎯 Target label: SR
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\by_component_log_SR.pkl
#       ✅ Performance - PLCC: 0.2969, SRCC: 0.2932, KRCC: 0.1991, RMSE: 1.1265
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\by_component_log_SR.pkl
#       ✅ Performance - PLCC: 0.7238, SRCC: 0.7321, KRCC: 0.5424, RMSE: 0.4687
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\by_component_log_SR.pkl
#       ✅ Performance - PLCC: 0.7304, SRCC: 0.7388, KRCC: 0.5470, RMSE: 0.4649
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\by_component_log_SR.pkl
#       ✅ Performance - PLCC: 0.6372, SRCC: 0.6237, KRCC: 0.4478, RMSE: 0.5351
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\by_component_log_SR.pkl
#       ✅ Performance - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\by_component_log_SR.pkl
#       ✅ Performance - PLCC: 0.7111, SRCC: 0.7139, KRCC: 0.5227, RMSE: 0.4778
#
#   🎯 Target label: S
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\by_component_log_S.pkl
#       ✅ Performance - PLCC: 0.5413, SRCC: 0.5694, KRCC: 0.4010, RMSE: 0.9381
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\by_component_log_S.pkl
#       ✅ Performance - PLCC: 0.8304, SRCC: 0.8346, KRCC: 0.6378, RMSE: 0.4373
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\by_component_log_S.pkl
#       ✅ Performance - PLCC: 0.8323, SRCC: 0.8326, KRCC: 0.6322, RMSE: 0.4343
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\by_component_log_S.pkl
#       ✅ Performance - PLCC: 0.7742, SRCC: 0.7700, KRCC: 0.5682, RMSE: 0.4959
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\by_component_log_S.pkl
#       ✅ Performance - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\by_component_log_S.pkl
#       ✅ Performance - PLCC: 0.8300, SRCC: 0.8196, KRCC: 0.6208, RMSE: 0.4385
#
#   🎯 Target label: U
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\by_component_log_U.pkl
#       ✅ Performance - PLCC: 0.4209, SRCC: 0.4457, KRCC: 0.3099, RMSE: 0.9844
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\by_component_log_U.pkl
#       ✅ Performance - PLCC: 0.8093, SRCC: 0.8126, KRCC: 0.6153, RMSE: 0.4609
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\by_component_log_U.pkl
#       ✅ Performance - PLCC: 0.7976, SRCC: 0.7999, KRCC: 0.5999, RMSE: 0.4723
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\by_component_log_U.pkl
#       ✅ Performance - PLCC: 0.7401, SRCC: 0.7312, KRCC: 0.5394, RMSE: 0.5288
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\by_component_log_U.pkl
#       ✅ Performance - PLCC: 0.7841, SRCC: 0.7902, KRCC: 0.5926, RMSE: 0.4898
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\by_component_log_U.pkl
#       ✅ Performance - PLCC: 0.7887, SRCC: 0.7858, KRCC: 0.5848, RMSE: 0.4805
#
#   🎯 Target label: O
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\by_component_log_O.pkl
#       ✅ Performance - PLCC: 0.5499, SRCC: 0.5823, KRCC: 0.4156, RMSE: 1.2302
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\by_component_log_O.pkl
#       ✅ Performance - PLCC: 0.8406, SRCC: 0.8376, KRCC: 0.6441, RMSE: 0.5845
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\by_component_log_O.pkl
#       ✅ Performance - PLCC: 0.8322, SRCC: 0.8293, KRCC: 0.6394, RMSE: 0.5989
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\by_component_log_O.pkl
#       ✅ Performance - PLCC: 0.7851, SRCC: 0.7781, KRCC: 0.5879, RMSE: 0.6742
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\by_component_log_O.pkl
#       ✅ Performance - PLCC: 0.8286, SRCC: 0.8203, KRCC: 0.6318, RMSE: 0.6064
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\by_component_log_O.pkl
#       ✅ Performance - PLCC: 0.8470, SRCC: 0.8386, KRCC: 0.6471, RMSE: 0.5735
#
# 📊 Dataset: s_only_log
#     Features loaded: s_only_log.csv, Shape: (1000, 1152)
#
#   🎯 Target label: TSV
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_log_TSV.pkl
#       ✅ Performance - PLCC: 0.6052, SRCC: 0.6182, KRCC: 0.4372, RMSE: 0.6982
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\s_only_log_TSV.pkl
#       ✅ Performance - PLCC: 0.8483, SRCC: 0.8270, KRCC: 0.6410, RMSE: 0.3540
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_log_TSV.pkl
#       ✅ Performance - PLCC: 0.8394, SRCC: 0.8122, KRCC: 0.6274, RMSE: 0.3634
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_log_TSV.pkl
#       ✅ Performance - PLCC: 0.7908, SRCC: 0.7597, KRCC: 0.5755, RMSE: 0.4061
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_log_TSV.pkl
#       ✅ Performance - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\s_only_log_TSV.pkl
#       ✅ Performance - PLCC: 0.8329, SRCC: 0.8019, KRCC: 0.6170, RMSE: 0.3706
#
#   🎯 Target label: B
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_log_B.pkl
#       ✅ Performance - PLCC: 0.4477, SRCC: 0.4640, KRCC: 0.3235, RMSE: 1.2661
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\s_only_log_B.pkl
#       ✅ Performance - PLCC: 0.6818, SRCC: 0.6545, KRCC: 0.4738, RMSE: 0.5957
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_log_B.pkl
#       ✅ Performance - PLCC: 0.6928, SRCC: 0.6712, KRCC: 0.4901, RMSE: 0.5867
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_log_B.pkl
#       ✅ Performance - PLCC: 0.6507, SRCC: 0.6033, KRCC: 0.4348, RMSE: 0.6223
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_log_B.pkl
#       ✅ Performance - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\s_only_log_B.pkl
#       ✅ Performance - PLCC: 0.6732, SRCC: 0.6574, KRCC: 0.4763, RMSE: 0.6207
#
#   🎯 Target label: SR
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_log_SR.pkl
#       ✅ Performance - PLCC: 0.3131, SRCC: 0.3052, KRCC: 0.2058, RMSE: 1.0946
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\s_only_log_SR.pkl
#       ✅ Performance - PLCC: 0.7052, SRCC: 0.7095, KRCC: 0.5186, RMSE: 0.4815
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_log_SR.pkl
#       ✅ Performance - PLCC: 0.7042, SRCC: 0.7095, KRCC: 0.5207, RMSE: 0.4832
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_log_SR.pkl
#       ✅ Performance - PLCC: 0.6372, SRCC: 0.6235, KRCC: 0.4476, RMSE: 0.5351
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_log_SR.pkl
#       ✅ Performance - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\s_only_log_SR.pkl
#       ✅ Performance - PLCC: 0.6837, SRCC: 0.6742, KRCC: 0.4884, RMSE: 0.4953
#
#   🎯 Target label: S
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_log_S.pkl
#       ✅ Performance - PLCC: 0.5444, SRCC: 0.5716, KRCC: 0.4036, RMSE: 0.9133
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\s_only_log_S.pkl
#       ✅ Performance - PLCC: 0.8178, SRCC: 0.8206, KRCC: 0.6210, RMSE: 0.4516
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_log_S.pkl
#       ✅ Performance - PLCC: 0.8197, SRCC: 0.8204, KRCC: 0.6202, RMSE: 0.4488
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_log_S.pkl
#       ✅ Performance - PLCC: 0.7742, SRCC: 0.7703, KRCC: 0.5687, RMSE: 0.4959
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_log_S.pkl
#       ✅ Performance - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\s_only_log_S.pkl
#       ✅ Performance - PLCC: 0.8104, SRCC: 0.8005, KRCC: 0.5990, RMSE: 0.4595
#
#   🎯 Target label: U
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_log_U.pkl
#       ✅ Performance - PLCC: 0.4518, SRCC: 0.4587, KRCC: 0.3170, RMSE: 0.9166
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\s_only_log_U.pkl
#       ✅ Performance - PLCC: 0.7909, SRCC: 0.7957, KRCC: 0.5994, RMSE: 0.4792
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_log_U.pkl
#       ✅ Performance - PLCC: 0.7787, SRCC: 0.7805, KRCC: 0.5831, RMSE: 0.4906
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_log_U.pkl
#       ✅ Performance - PLCC: 0.7399, SRCC: 0.7308, KRCC: 0.5393, RMSE: 0.5289
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_log_U.pkl
#       ✅ Performance - PLCC: 0.7841, SRCC: 0.7902, KRCC: 0.5926, RMSE: 0.4898
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\s_only_log_U.pkl
#       ✅ Performance - PLCC: 0.7643, SRCC: 0.7706, KRCC: 0.5706, RMSE: 0.5033
#
#   🎯 Target label: O
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_log_O.pkl
#       ✅ Performance - PLCC: 0.5576, SRCC: 0.5819, KRCC: 0.4200, RMSE: 1.2079
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\s_only_log_O.pkl
#       ✅ Performance - PLCC: 0.8327, SRCC: 0.8319, KRCC: 0.6379, RMSE: 0.5979
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_log_O.pkl
#       ✅ Performance - PLCC: 0.8189, SRCC: 0.8153, KRCC: 0.6244, RMSE: 0.6197
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_log_O.pkl
#       ✅ Performance - PLCC: 0.7851, SRCC: 0.7780, KRCC: 0.5879, RMSE: 0.6741
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_log_O.pkl
#       ✅ Performance - PLCC: 0.8286, SRCC: 0.8203, KRCC: 0.6318, RMSE: 0.6064
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\s_only_log_O.pkl
#       ✅ Performance - PLCC: 0.8395, SRCC: 0.8361, KRCC: 0.6440, RMSE: 0.5874
#
# ============================================================
# Completed scaling method: LOG
# ============================================================
#
# 🔄 Processing scaling method: LOG1P
# ------------------------------------------------------------
#
# 📊 Dataset: all_features_log1p
#     Features loaded: all_features_log1p.csv, Shape: (1000, 1152)
#
#   🎯 Target label: TSV
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\all_features_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.6204, SRCC: 0.6233, KRCC: 0.4460, RMSE: 0.6645
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\all_features_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.8444, SRCC: 0.8259, KRCC: 0.6380, RMSE: 0.3584
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\all_features_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.8317, SRCC: 0.8028, KRCC: 0.6184, RMSE: 0.3724
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\all_features_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.7908, SRCC: 0.7597, KRCC: 0.5756, RMSE: 0.4061
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\all_features_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\all_features_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.8368, SRCC: 0.8055, KRCC: 0.6206, RMSE: 0.3662
#
#   🎯 Target label: B
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\all_features_log1p_B.pkl
#       ✅ Performance - PLCC: 0.4399, SRCC: 0.4476, KRCC: 0.3131, RMSE: 1.2319
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\all_features_log1p_B.pkl
#       ✅ Performance - PLCC: 0.6926, SRCC: 0.6765, KRCC: 0.4925, RMSE: 0.5909
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\all_features_log1p_B.pkl
#       ✅ Performance - PLCC: 0.6863, SRCC: 0.6625, KRCC: 0.4776, RMSE: 0.5913
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\all_features_log1p_B.pkl
#       ✅ Performance - PLCC: 0.6507, SRCC: 0.6033, KRCC: 0.4348, RMSE: 0.6223
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\all_features_log1p_B.pkl
#       ✅ Performance - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\all_features_log1p_B.pkl
#       ✅ Performance - PLCC: 0.6723, SRCC: 0.6511, KRCC: 0.4675, RMSE: 0.6105
#
#   🎯 Target label: SR
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\all_features_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.3255, SRCC: 0.3255, KRCC: 0.2224, RMSE: 1.0816
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\all_features_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.7165, SRCC: 0.7314, KRCC: 0.5380, RMSE: 0.4760
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\all_features_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.6951, SRCC: 0.6943, KRCC: 0.5094, RMSE: 0.4900
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\all_features_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.6371, SRCC: 0.6236, KRCC: 0.4477, RMSE: 0.5351
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\all_features_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\all_features_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.7120, SRCC: 0.7151, KRCC: 0.5237, RMSE: 0.4770
#
#   🎯 Target label: S
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\all_features_log1p_S.pkl
#       ✅ Performance - PLCC: 0.5289, SRCC: 0.5591, KRCC: 0.3968, RMSE: 0.9298
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\all_features_log1p_S.pkl
#       ✅ Performance - PLCC: 0.8247, SRCC: 0.8231, KRCC: 0.6283, RMSE: 0.4448
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\all_features_log1p_S.pkl
#       ✅ Performance - PLCC: 0.8079, SRCC: 0.8044, KRCC: 0.6018, RMSE: 0.4621
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\all_features_log1p_S.pkl
#       ✅ Performance - PLCC: 0.7742, SRCC: 0.7701, KRCC: 0.5684, RMSE: 0.4959
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\all_features_log1p_S.pkl
#       ✅ Performance - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\all_features_log1p_S.pkl
#       ✅ Performance - PLCC: 0.8282, SRCC: 0.8190, KRCC: 0.6215, RMSE: 0.4391
#
#   🎯 Target label: U
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\all_features_log1p_U.pkl
#       ✅ Performance - PLCC: 0.4703, SRCC: 0.4641, KRCC: 0.3295, RMSE: 0.8737
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\all_features_log1p_U.pkl
#       ✅ Performance - PLCC: 0.7981, SRCC: 0.7993, KRCC: 0.6034, RMSE: 0.4713
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\all_features_log1p_U.pkl
#       ✅ Performance - PLCC: 0.7745, SRCC: 0.7694, KRCC: 0.5739, RMSE: 0.4946
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\all_features_log1p_U.pkl
#       ✅ Performance - PLCC: 0.7400, SRCC: 0.7309, KRCC: 0.5393, RMSE: 0.5288
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\all_features_log1p_U.pkl
#       ✅ Performance - PLCC: 0.7841, SRCC: 0.7902, KRCC: 0.5926, RMSE: 0.4898
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\all_features_log1p_U.pkl
#       ✅ Performance - PLCC: 0.7978, SRCC: 0.8024, KRCC: 0.6080, RMSE: 0.4744
#
#   🎯 Target label: O
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\all_features_log1p_O.pkl
#       ✅ Performance - PLCC: 0.5479, SRCC: 0.5731, KRCC: 0.4173, RMSE: 1.1840
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\all_features_log1p_O.pkl
#       ✅ Performance - PLCC: 0.8345, SRCC: 0.8325, KRCC: 0.6405, RMSE: 0.5951
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\all_features_log1p_O.pkl
#       ✅ Performance - PLCC: 0.8150, SRCC: 0.8259, KRCC: 0.6336, RMSE: 0.6344
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\all_features_log1p_O.pkl
#       ✅ Performance - PLCC: 0.7855, SRCC: 0.7783, KRCC: 0.5878, RMSE: 0.6736
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\all_features_log1p_O.pkl
#       ✅ Performance - PLCC: 0.8286, SRCC: 0.8203, KRCC: 0.6318, RMSE: 0.6064
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\all_features_log1p_O.pkl
#       ✅ Performance - PLCC: 0.8264, SRCC: 0.8139, KRCC: 0.6241, RMSE: 0.6081
#
# 📊 Dataset: by_component_log1p
#     Features loaded: by_component_log1p.csv, Shape: (1000, 1152)
#
#   🎯 Target label: TSV
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\by_component_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.6218, SRCC: 0.6245, KRCC: 0.4475, RMSE: 0.6618
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\by_component_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.8441, SRCC: 0.8247, KRCC: 0.6377, RMSE: 0.3585
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\by_component_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.8306, SRCC: 0.8009, KRCC: 0.6156, RMSE: 0.3736
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\by_component_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.7908, SRCC: 0.7599, KRCC: 0.5758, RMSE: 0.4061
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\by_component_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\by_component_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.8411, SRCC: 0.8240, KRCC: 0.6397, RMSE: 0.3603
#
#   🎯 Target label: B
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\by_component_log1p_B.pkl
#       ✅ Performance - PLCC: 0.4419, SRCC: 0.4476, KRCC: 0.3123, RMSE: 1.2181
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\by_component_log1p_B.pkl
#       ✅ Performance - PLCC: 0.6890, SRCC: 0.6706, KRCC: 0.4872, RMSE: 0.5935
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\by_component_log1p_B.pkl
#       ✅ Performance - PLCC: 0.6851, SRCC: 0.6605, KRCC: 0.4759, RMSE: 0.5921
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\by_component_log1p_B.pkl
#       ✅ Performance - PLCC: 0.6507, SRCC: 0.6033, KRCC: 0.4348, RMSE: 0.6223
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\by_component_log1p_B.pkl
#       ✅ Performance - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\by_component_log1p_B.pkl
#       ✅ Performance - PLCC: 0.6846, SRCC: 0.6683, KRCC: 0.4847, RMSE: 0.6003
#
#   🎯 Target label: SR
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\by_component_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.3259, SRCC: 0.3251, KRCC: 0.2223, RMSE: 1.0797
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\by_component_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.7128, SRCC: 0.7277, KRCC: 0.5339, RMSE: 0.4795
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\by_component_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.6839, SRCC: 0.6975, KRCC: 0.5031, RMSE: 0.5118
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\by_component_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.6371, SRCC: 0.6236, KRCC: 0.4477, RMSE: 0.5351
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\by_component_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\by_component_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.7328, SRCC: 0.7299, KRCC: 0.5373, RMSE: 0.4619
#
#   🎯 Target label: S
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\by_component_log1p_S.pkl
#       ✅ Performance - PLCC: 0.5279, SRCC: 0.5554, KRCC: 0.3947, RMSE: 0.9276
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\by_component_log1p_S.pkl
#       ✅ Performance - PLCC: 0.8227, SRCC: 0.8218, KRCC: 0.6257, RMSE: 0.4469
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\by_component_log1p_S.pkl
#       ✅ Performance - PLCC: 0.8061, SRCC: 0.8025, KRCC: 0.6001, RMSE: 0.4641
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\by_component_log1p_S.pkl
#       ✅ Performance - PLCC: 0.7742, SRCC: 0.7701, KRCC: 0.5684, RMSE: 0.4959
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\by_component_log1p_S.pkl
#       ✅ Performance - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\by_component_log1p_S.pkl
#       ✅ Performance - PLCC: 0.8308, SRCC: 0.8284, KRCC: 0.6276, RMSE: 0.4367
#
#   🎯 Target label: U
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\by_component_log1p_U.pkl
#       ✅ Performance - PLCC: 0.4752, SRCC: 0.4678, KRCC: 0.3291, RMSE: 0.8658
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\by_component_log1p_U.pkl
#       ✅ Performance - PLCC: 0.8031, SRCC: 0.8055, KRCC: 0.6100, RMSE: 0.4659
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\by_component_log1p_U.pkl
#       ✅ Performance - PLCC: 0.7730, SRCC: 0.7671, KRCC: 0.5715, RMSE: 0.4960
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\by_component_log1p_U.pkl
#       ✅ Performance - PLCC: 0.7401, SRCC: 0.7310, KRCC: 0.5394, RMSE: 0.5288
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\by_component_log1p_U.pkl
#       ✅ Performance - PLCC: 0.7674, SRCC: 0.7692, KRCC: 0.5674, RMSE: 0.5040
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\by_component_log1p_U.pkl
#       ✅ Performance - PLCC: 0.7928, SRCC: 0.7936, KRCC: 0.6013, RMSE: 0.4796
#
#   🎯 Target label: O
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\by_component_log1p_O.pkl
#       ✅ Performance - PLCC: 0.5492, SRCC: 0.5736, KRCC: 0.4172, RMSE: 1.1828
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\by_component_log1p_O.pkl
#       ✅ Performance - PLCC: 0.8335, SRCC: 0.8305, KRCC: 0.6386, RMSE: 0.5967
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\by_component_log1p_O.pkl
#       ✅ Performance - PLCC: 0.8169, SRCC: 0.8269, KRCC: 0.6356, RMSE: 0.6305
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\by_component_log1p_O.pkl
#       ✅ Performance - PLCC: 0.7851, SRCC: 0.7781, KRCC: 0.5880, RMSE: 0.6741
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\by_component_log1p_O.pkl
#       ✅ Performance - PLCC: 0.8286, SRCC: 0.8203, KRCC: 0.6318, RMSE: 0.6064
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\by_component_log1p_O.pkl
#       ✅ Performance - PLCC: 0.8173, SRCC: 0.8054, KRCC: 0.6144, RMSE: 0.6225
#
# 📊 Dataset: s_only_log1p
#     Features loaded: s_only_log1p.csv, Shape: (1000, 1152)
#
#   🎯 Target label: TSV
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.6130, SRCC: 0.6134, KRCC: 0.4395, RMSE: 0.6813
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\s_only_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.8473, SRCC: 0.8283, KRCC: 0.6425, RMSE: 0.3551
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.8370, SRCC: 0.8131, KRCC: 0.6290, RMSE: 0.3663
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.7908, SRCC: 0.7597, KRCC: 0.5756, RMSE: 0.4061
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\s_only_log1p_TSV.pkl
#       ✅ Performance - PLCC: 0.8452, SRCC: 0.8251, KRCC: 0.6418, RMSE: 0.3568
#
#   🎯 Target label: B
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_log1p_B.pkl
#       ✅ Performance - PLCC: 0.4322, SRCC: 0.4489, KRCC: 0.3129, RMSE: 1.2870
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\s_only_log1p_B.pkl
#       ✅ Performance - PLCC: 0.6887, SRCC: 0.6684, KRCC: 0.4858, RMSE: 0.5900
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_log1p_B.pkl
#       ✅ Performance - PLCC: 0.6931, SRCC: 0.6774, KRCC: 0.4913, RMSE: 0.5858
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_log1p_B.pkl
#       ✅ Performance - PLCC: 0.6507, SRCC: 0.6033, KRCC: 0.4348, RMSE: 0.6223
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_log1p_B.pkl
#       ✅ Performance - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\s_only_log1p_B.pkl
#       ✅ Performance - PLCC: 0.6815, SRCC: 0.6611, KRCC: 0.4840, RMSE: 0.6039
#
#   🎯 Target label: SR
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.3235, SRCC: 0.3224, KRCC: 0.2177, RMSE: 1.0852
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\s_only_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.7124, SRCC: 0.7137, KRCC: 0.5230, RMSE: 0.4766
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.7103, SRCC: 0.7153, KRCC: 0.5239, RMSE: 0.4798
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.6371, SRCC: 0.6235, KRCC: 0.4476, RMSE: 0.5351
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\s_only_log1p_SR.pkl
#       ✅ Performance - PLCC: 0.7181, SRCC: 0.7200, KRCC: 0.5271, RMSE: 0.4733
#
#   🎯 Target label: S
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_log1p_S.pkl
#       ✅ Performance - PLCC: 0.5278, SRCC: 0.5599, KRCC: 0.3980, RMSE: 0.9425
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\s_only_log1p_S.pkl
#       ✅ Performance - PLCC: 0.8214, SRCC: 0.8227, KRCC: 0.6245, RMSE: 0.4473
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_log1p_S.pkl
#       ✅ Performance - PLCC: 0.8156, SRCC: 0.8129, KRCC: 0.6110, RMSE: 0.4537
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_log1p_S.pkl
#       ✅ Performance - PLCC: 0.7742, SRCC: 0.7703, KRCC: 0.5687, RMSE: 0.4959
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_log1p_S.pkl
#       ✅ Performance - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\s_only_log1p_S.pkl
#       ✅ Performance - PLCC: 0.8276, SRCC: 0.8222, KRCC: 0.6201, RMSE: 0.4397
#
#   🎯 Target label: U
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_log1p_U.pkl
#       ✅ Performance - PLCC: 0.4481, SRCC: 0.4424, KRCC: 0.3132, RMSE: 0.9128
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\s_only_log1p_U.pkl
#       ✅ Performance - PLCC: 0.7942, SRCC: 0.7945, KRCC: 0.5991, RMSE: 0.4765
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_log1p_U.pkl
#       ✅ Performance - PLCC: 0.7789, SRCC: 0.7744, KRCC: 0.5797, RMSE: 0.4900
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_log1p_U.pkl
#       ✅ Performance - PLCC: 0.7400, SRCC: 0.7306, KRCC: 0.5392, RMSE: 0.5288
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_log1p_U.pkl
#       ✅ Performance - PLCC: 0.7841, SRCC: 0.7902, KRCC: 0.5926, RMSE: 0.4898
#
#     🤖 Model: mlp
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./mlp\s_only_log1p_U.pkl
#       ✅ Performance - PLCC: 0.7602, SRCC: 0.7566, KRCC: 0.5591, RMSE: 0.5073
#
#   🎯 Target label: O
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_log1p_O.pkl
#       ✅ Performance - PLCC: 0.5403, SRCC: 0.5726, KRCC: 0.4148, RMSE: 1.2086
#
#     🤖 Model: ridge_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./ridge_regression\s_only_log1p_O.pkl
#       ✅ Performance - PLCC: 0.8344, SRCC: 0.8309, KRCC: 0.6377, RMSE: 0.5951
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_log1p_O.pkl
#       ✅ Performance - PLCC: 0.8149, SRCC: 0.8107, KRCC: 0.6177, RMSE: 0.6264
#
# ...
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\by_component_standard_S.pkl
#       ✅ Performance - PLCC: 0.3780, SRCC: 0.3699, KRCC: 0.2567, RMSE: 1.5228
#
#     🤖 Model: ridge_regression
#     Training ridge_regression...
#       Best parameters: {'solver': 'sparse_cg', 'max_iter': 2000, 'alpha': 1000}
#       Model saved: ./ridge_regression\by_component_standard_S.pkl
#       ✅ Performance - PLCC: 0.8284, SRCC: 0.8394, KRCC: 0.6395, RMSE: 0.4394
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\by_component_standard_S.pkl
#       ✅ Performance - PLCC: 0.8776, SRCC: 0.8709, KRCC: 0.6824, RMSE: 0.3780
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\by_component_standard_S.pkl
#       ✅ Performance - PLCC: 0.7742, SRCC: 0.7703, KRCC: 0.5686, RMSE: 0.4960
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\by_component_standard_S.pkl
#       ✅ Performance - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#
#     🤖 Model: mlp
#     Training mlp...
#       Best parameters: {'solver': 'sgd', 'max_iter': 1000, 'learning_rate': 'constant', 'hidden_layer_sizes': (50,), 'alpha': 0.001, 'activation': 'logistic'}
#       Model saved: ./mlp\by_component_standard_S.pkl
#       ✅ Performance - PLCC: 0.8459, SRCC: 0.8481, KRCC: 0.6500, RMSE: 0.4183
#
#   🎯 Target label: U
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\by_component_standard_U.pkl
#       ✅ Performance - PLCC: 0.2619, SRCC: 0.2864, KRCC: 0.1974, RMSE: 1.6558
#
#     🤖 Model: ridge_regression
#     Training ridge_regression...
#       Best parameters: {'solver': 'sparse_cg', 'max_iter': 2000, 'alpha': 1000}
#       Model saved: ./ridge_regression\by_component_standard_U.pkl
#       ✅ Performance - PLCC: 0.8026, SRCC: 0.8095, KRCC: 0.6103, RMSE: 0.4689
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\by_component_standard_U.pkl
#       ✅ Performance - PLCC: 0.8510, SRCC: 0.8504, KRCC: 0.6552, RMSE: 0.4230
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\by_component_standard_U.pkl
#       ✅ Performance - PLCC: 0.7399, SRCC: 0.7305, KRCC: 0.5390, RMSE: 0.5289
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\by_component_standard_U.pkl
#       ✅ Performance - PLCC: 0.7841, SRCC: 0.7902, KRCC: 0.5926, RMSE: 0.4898
#
#     🤖 Model: mlp
#     Training mlp...
#       Best parameters: {'solver': 'adam', 'max_iter': 1000, 'learning_rate': 'constant', 'hidden_layer_sizes': (100, 100), 'alpha': 0.01, 'activation': 'logistic'}
#       Model saved: ./mlp\by_component_standard_U.pkl
#       ✅ Performance - PLCC: 0.8250, SRCC: 0.8218, KRCC: 0.6256, RMSE: 0.4404
#
#   🎯 Target label: O
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\by_component_standard_O.pkl
#       ✅ Performance - PLCC: 0.4323, SRCC: 0.4302, KRCC: 0.3009, RMSE: 1.7924
#
#     🤖 Model: ridge_regression
#     Training ridge_regression...
#       Best parameters: {'solver': 'sparse_cg', 'max_iter': 2000, 'alpha': 1000}
#       Model saved: ./ridge_regression\by_component_standard_O.pkl
#       ✅ Performance - PLCC: 0.8306, SRCC: 0.8361, KRCC: 0.6377, RMSE: 0.6016
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\by_component_standard_O.pkl
#       ✅ Performance - PLCC: 0.8705, SRCC: 0.8675, KRCC: 0.6807, RMSE: 0.5350
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\by_component_standard_O.pkl
#       ✅ Performance - PLCC: 0.7851, SRCC: 0.7778, KRCC: 0.5877, RMSE: 0.6741
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\by_component_standard_O.pkl
#       ✅ Performance - PLCC: 0.8286, SRCC: 0.8203, KRCC: 0.6318, RMSE: 0.6064
#
#     🤖 Model: mlp
#     Training mlp...
#       Best parameters: {'solver': 'sgd', 'max_iter': 1000, 'learning_rate': 'constant', 'hidden_layer_sizes': (50,), 'alpha': 0.001, 'activation': 'logistic'}
#       Model saved: ./mlp\by_component_standard_O.pkl
#       ✅ Performance - PLCC: 0.8503, SRCC: 0.8475, KRCC: 0.6517, RMSE: 0.5681
#
# 📊 Dataset: s_only_standard
#     Features loaded: s_only_standard.csv, Shape: (1000, 1152)
#
#   🎯 Target label: TSV
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_standard_TSV.pkl
#       ✅ Performance - PLCC: 0.5869, SRCC: 0.6248, KRCC: 0.4463, RMSE: 0.7320
#
#     🤖 Model: ridge_regression
#     Training ridge_regression...
#       Best parameters: {'solver': 'cholesky', 'max_iter': 1000, 'alpha': 1}
#       Model saved: ./ridge_regression\s_only_standard_TSV.pkl
#       ✅ Performance - PLCC: 0.8154, SRCC: 0.8069, KRCC: 0.6241, RMSE: 0.3898
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_standard_TSV.pkl
#       ✅ Performance - PLCC: 0.8228, SRCC: 0.7788, KRCC: 0.5958, RMSE: 0.3821
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_standard_TSV.pkl
#       ✅ Performance - PLCC: 0.7909, SRCC: 0.7597, KRCC: 0.5756, RMSE: 0.4061
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_standard_TSV.pkl
#       ✅ Performance - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#
#     🤖 Model: mlp
#     Training mlp...
#       Best parameters: {'solver': 'adam', 'max_iter': 1000, 'learning_rate': 'constant', 'hidden_layer_sizes': (100, 100), 'alpha': 0.01, 'activation': 'logistic'}
#       Model saved: ./mlp\s_only_standard_TSV.pkl
#       ✅ Performance - PLCC: 0.8162, SRCC: 0.7813, KRCC: 0.6007, RMSE: 0.3832
#
#   🎯 Target label: B
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_standard_B.pkl
#       ✅ Performance - PLCC: 0.4510, SRCC: 0.4205, KRCC: 0.2872, RMSE: 1.2736
#
#     🤖 Model: ridge_regression
#     Training ridge_regression...
#       Best parameters: {'solver': 'lsqr', 'max_iter': 2000, 'alpha': 10}
#       Model saved: ./ridge_regression\s_only_standard_B.pkl
#       ✅ Performance - PLCC: 0.6657, SRCC: 0.6454, KRCC: 0.4627, RMSE: 0.6106
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_standard_B.pkl
#       ✅ Performance - PLCC: 0.7004, SRCC: 0.6628, KRCC: 0.4840, RMSE: 0.5841
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_standard_B.pkl
#       ✅ Performance - PLCC: 0.6529, SRCC: 0.6047, KRCC: 0.4376, RMSE: 0.6230
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_standard_B.pkl
#       ✅ Performance - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#
#     🤖 Model: mlp
#     Training mlp...
#       Best parameters: {'solver': 'sgd', 'max_iter': 2000, 'learning_rate': 'constant', 'hidden_layer_sizes': (100, 50, 25), 'alpha': 0.001, 'activation': 'relu'}
#       Model saved: ./mlp\s_only_standard_B.pkl
#       ✅ Performance - PLCC: 0.6580, SRCC: 0.6260, KRCC: 0.4493, RMSE: 0.6113
#
#   🎯 Target label: SR
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_standard_SR.pkl
#       ✅ Performance - PLCC: 0.3284, SRCC: 0.3519, KRCC: 0.2413, RMSE: 1.1737
#
#     🤖 Model: ridge_regression
#     Training ridge_regression...
#       Best parameters: {'solver': 'cholesky', 'max_iter': 1000, 'alpha': 1}
#       Model saved: ./ridge_regression\s_only_standard_SR.pkl
#       ✅ Performance - PLCC: 0.6680, SRCC: 0.6918, KRCC: 0.4978, RMSE: 0.5167
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_standard_SR.pkl
#       ✅ Performance - PLCC: 0.7000, SRCC: 0.6995, KRCC: 0.5119, RMSE: 0.4935
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_standard_SR.pkl
#       ✅ Performance - PLCC: 0.6370, SRCC: 0.6236, KRCC: 0.4477, RMSE: 0.5352
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_standard_SR.pkl
#       ✅ Performance - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#
#     🤖 Model: mlp
#     Training mlp...
#       Best parameters: {'solver': 'adam', 'max_iter': 2000, 'learning_rate': 'invscaling', 'hidden_layer_sizes': (50, 50), 'alpha': 0.0001, 'activation': 'relu'}
#       Model saved: ./mlp\s_only_standard_SR.pkl
#       ✅ Performance - PLCC: 0.6036, SRCC: 0.5983, KRCC: 0.4324, RMSE: 0.5418
#
#   🎯 Target label: S
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_standard_S.pkl
#       ✅ Performance - PLCC: 0.5041, SRCC: 0.5339, KRCC: 0.3792, RMSE: 1.0325
#
#     🤖 Model: ridge_regression
#     Training ridge_regression...
#       Best parameters: {'solver': 'sparse_cg', 'max_iter': 2000, 'alpha': 1}
#       Model saved: ./ridge_regression\s_only_standard_S.pkl
#       ✅ Performance - PLCC: 0.8031, SRCC: 0.8136, KRCC: 0.6225, RMSE: 0.4725
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_standard_S.pkl
#       ✅ Performance - PLCC: 0.8220, SRCC: 0.8245, KRCC: 0.6345, RMSE: 0.4539
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_standard_S.pkl
#       ✅ Performance - PLCC: 0.7742, SRCC: 0.7703, KRCC: 0.5686, RMSE: 0.4960
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_standard_S.pkl
#       ✅ Performance - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#
#     🤖 Model: mlp
#     Training mlp...
#       Best parameters: {'solver': 'adam', 'max_iter': 2000, 'learning_rate': 'invscaling', 'hidden_layer_sizes': (50, 50), 'alpha': 0.0001, 'activation': 'relu'}
#       Model saved: ./mlp\s_only_standard_S.pkl
#       ✅ Performance - PLCC: 0.7719, SRCC: 0.7578, KRCC: 0.5586, RMSE: 0.5026
#
#   🎯 Target label: U
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_standard_U.pkl
#       ✅ Performance - PLCC: 0.4218, SRCC: 0.4428, KRCC: 0.3155, RMSE: 1.0046
#
#     🤖 Model: ridge_regression
#     Training ridge_regression...
#       Best parameters: {'solver': 'sparse_cg', 'max_iter': 2000, 'alpha': 1}
#       Model saved: ./ridge_regression\s_only_standard_U.pkl
#       ✅ Performance - PLCC: 0.7687, SRCC: 0.7883, KRCC: 0.5957, RMSE: 0.4990
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_standard_U.pkl
#       ✅ Performance - PLCC: 0.8100, SRCC: 0.8075, KRCC: 0.6106, RMSE: 0.4576
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_standard_U.pkl
#       ✅ Performance - PLCC: 0.7399, SRCC: 0.7305, KRCC: 0.5390, RMSE: 0.5289
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_standard_U.pkl
#       ✅ Performance - PLCC: 0.7841, SRCC: 0.7902, KRCC: 0.5926, RMSE: 0.4898
#
#     🤖 Model: mlp
#     Training mlp...
#       Best parameters: {'solver': 'adam', 'max_iter': 2000, 'learning_rate': 'invscaling', 'hidden_layer_sizes': (100, 50, 25), 'alpha': 0.001, 'activation': 'logistic'}
#       Model saved: ./mlp\s_only_standard_U.pkl
#       ✅ Performance - PLCC: 0.7846, SRCC: 0.7686, KRCC: 0.5728, RMSE: 0.4845
#
#   🎯 Target label: O
#     📈 Training samples: 800, Test samples: 200
#
#     🤖 Model: linear_regression
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./linear_regression\s_only_standard_O.pkl
#       ✅ Performance - PLCC: 0.5085, SRCC: 0.5626, KRCC: 0.4039, RMSE: 1.3379
#
#     🤖 Model: ridge_regression
#     Training ridge_regression...
#       Best parameters: {'solver': 'cholesky', 'max_iter': 1000, 'alpha': 1}
#       Model saved: ./ridge_regression\s_only_standard_O.pkl
#       ✅ Performance - PLCC: 0.8040, SRCC: 0.8188, KRCC: 0.6265, RMSE: 0.6462
#
#     🤖 Model: svr
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./svr\s_only_standard_O.pkl
#       ✅ Performance - PLCC: 0.8369, SRCC: 0.8343, KRCC: 0.6468, RMSE: 0.5928
#
#     🤖 Model: random_forest
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./random_forest\s_only_standard_O.pkl
#       ✅ Performance - PLCC: 0.7851, SRCC: 0.7780, KRCC: 0.5879, RMSE: 0.6741
#
#     🤖 Model: gbm
#       ⏭️  Model already exists, loading...
#       Loaded existing model: ./gbm\s_only_standard_O.pkl
#       ✅ Performance - PLCC: 0.8286, SRCC: 0.8203, KRCC: 0.6318, RMSE: 0.6064
#
#     🤖 Model: mlp
#     Training mlp...
#       Best parameters: {'solver': 'adam', 'max_iter': 500, 'learning_rate': 'constant', 'hidden_layer_sizes': (100, 100), 'alpha': 0.01, 'activation': 'relu'}
#       Model saved: ./mlp\s_only_standard_O.pkl
#       ✅ Performance - PLCC: 0.7851, SRCC: 0.7744, KRCC: 0.5846, RMSE: 0.6681
#
# ============================================================
# Completed scaling method: STANDARD
# ============================================================
#
# ================================================================================
# TRAINING COMPLETED!
# ================================================================================
# ✅ Successfully trained/loaded: 756/756 models
# ⏭️  Skipped (already existed): 697/756 models
# 🆕 Newly trained: 59/756 models
# ================================================================================
#
# 📊 Results saved to: ./training_results.csv
#
# ================================================================================
# 🏆 TRAINING RESULTS SUMMARY
# ================================================================================
#
# 🥇 BEST PERFORMING MODELS BY METRIC:
# --------------------------------------------------
#
#   📈 Best PLCC (Higher is better):
#      🎯 svr on all_features_power
#      📊 Label: S
#      🎖️  Score: 0.8854
#
#   📈 Best SRCC (Higher is better):
#      🎯 svr on all_features_power
#      📊 Label: S
#      🎖️  Score: 0.8792
#
#   📈 Best KRCC (Higher is better):
#      🎯 svr on all_features_power
#      📊 Label: S
#      🎖️  Score: 0.6931
#
#   📉 Best RMSE (Lower is better):
#      🎯 svr on all_features_power
#      📊 Label: TSV
#      🎖️  Score: 0.3158
#
#
# 📊 AVERAGE PERFORMANCE BY MODEL:
# --------------------------------------------------
#
#   🤖 GBM:
#      PLCC: 0.7704
#      SRCC: 0.7503
#      KRCC: 0.5628
#      RMSE: 0.5036
#
#   🤖 LINEAR_REGRESSION:
#      PLCC: 0.4062
#      SRCC: 0.4251
#      KRCC: 0.2972
#      RMSE: 1.3711
#
#   🤖 MLP:
#      PLCC: 0.7737
#      SRCC: 0.7626
#      KRCC: 0.5737
#      RMSE: 0.4959
#
#   🤖 RANDOM_FOREST:
#      PLCC: 0.7298
#      SRCC: 0.7110
#      KRCC: 0.5257
#      RMSE: 0.5438
#
#   🤖 RIDGE_REGRESSION:
#      PLCC: 0.7774
#      SRCC: 0.7744
#      KRCC: 0.5837
#      RMSE: 0.4961
#
#   🤖 SVR:
#      PLCC: 0.7972
#      SRCC: 0.7889
#      KRCC: 0.5996
#      RMSE: 0.4760
#
#
# 🏅 TOP 5 DATASET CONFIGURATIONS (by PLCC):
# --------------------------------------------------
#   #1 📊 all_features_log → TSV: 0.7931
#   #2 📊 s_only_log1p → TSV: 0.7928
#   #3 📊 by_component_log1p → TSV: 0.7920
#   #4 📊 by_component_log → TSV: 0.7919
#   #5 📊 all_features_log1p → TSV: 0.7912
#
# ================================================================================
#
#
#
# All models have been trained and saved!

# %%
results = pd.read_csv('./training_results.csv')
results = results.sort_values(by = ['label', 'PLCC'], ascending = [False, False])
results
# Out:
#     scaling_method  dataset_type           dataset_name label          model  \
# 377         robust  all_features    all_features_robust     U            svr
# 401         robust  by_component    by_component_robust     U            svr
# 449       standard  all_features  all_features_standard     U            svr
# 473       standard  by_component  by_component_standard     U            svr
# 233          power  all_features     all_features_power     U            svr
# 257          power  by_component     by_component_power     U            svr
# 305       quantile  all_features  all_features_quantile     U            svr
# 329       quantile  by_component  by_component_quantile     U            svr
# 161         minmax  all_features    all_features_minmax     U            svr
# 185         minmax  by_component    by_component_minmax     U            svr
# 281          power        s_only           s_only_power     U            svr
# 425         robust        s_only          s_only_robust     U            svr
# 497       standard        s_only        s_only_standard     U            svr
# 17             log  all_features       all_features_log     U            svr
# 209         minmax        s_only          s_only_minmax     U            svr
# 41             log  by_component       by_component_log     U            svr
# 307       quantile  all_features  all_features_quantile     U            gbm
# 331       quantile  by_component  by_component_quantile     U            gbm
# 19             log  all_features       all_features_log     U            gbm
# 43             log  by_component       by_component_log     U            gbm
# 67             log        s_only             s_only_log     U            gbm
# 91           log1p  all_features     all_features_log1p     U            gbm
# 139          log1p        s_only           s_only_log1p     U            gbm
# 163         minmax  all_features    all_features_minmax     U            gbm
# 187         minmax  by_component    by_component_minmax     U            gbm
# 211         minmax        s_only          s_only_minmax     U            gbm
# 235          power  all_features     all_features_power     U            gbm
# 259          power  by_component     by_component_power     U            gbm
# 283          power        s_only           s_only_power     U            gbm
# 379         robust  all_features    all_features_robust     U            gbm
# 403         robust  by_component    by_component_robust     U            gbm
# 427         robust        s_only          s_only_robust     U            gbm
# 451       standard  all_features  all_features_standard     U            gbm
# 475       standard  by_component  by_component_standard     U            gbm
# 499       standard        s_only        s_only_standard     U            gbm
# 355       quantile        s_only        s_only_quantile     U            gbm
# 137          log1p        s_only           s_only_log1p     U            svr
# 65             log        s_only             s_only_log     U            svr
# 89           log1p  all_features     all_features_log1p     U            svr
# 113          log1p  by_component     by_component_log1p     U            svr
# 115          log1p  by_component     by_component_log1p     U            gbm
# 353       quantile        s_only        s_only_quantile     U            svr
# 234          power  all_features     all_features_power     U  random_forest
# 258          power  by_component     by_component_power     U  random_forest
# 18             log  all_features       all_features_log     U  random_forest
# 42             log  by_component       by_component_log     U  random_forest
# 114          log1p  by_component     by_component_log1p     U  random_forest
# 282          power        s_only           s_only_power     U  random_forest
# 90           log1p  all_features     all_features_log1p     U  random_forest
# 138          log1p        s_only           s_only_log1p     U  random_forest
# 66             log        s_only             s_only_log     U  random_forest
# 210         minmax        s_only          s_only_minmax     U  random_forest
# 426         robust        s_only          s_only_robust     U  random_forest
# 498       standard        s_only        s_only_standard     U  random_forest
# 162         minmax  all_features    all_features_minmax     U  random_forest
# 186         minmax  by_component    by_component_minmax     U  random_forest
# 378         robust  all_features    all_features_robust     U  random_forest
# 402         robust  by_component    by_component_robust     U  random_forest
# 450       standard  all_features  all_features_standard     U  random_forest
# 474       standard  by_component  by_component_standard     U  random_forest
# 354       quantile        s_only        s_only_quantile     U  random_forest
# 306       quantile  all_features  all_features_quantile     U  random_forest
# 330       quantile  by_component  by_component_quantile     U  random_forest
# 217          power  all_features     all_features_power   TSV            svr
# 241          power  by_component     by_component_power   TSV            svr
# 433       standard  all_features  all_features_standard   TSV            svr
# 457       standard  by_component  by_component_standard   TSV            svr
# 361         robust  all_features    all_features_robust   TSV            svr
# 385         robust  by_component    by_component_robust   TSV            svr
# 289       quantile  all_features  all_features_quantile   TSV            svr
# 313       quantile  by_component  by_component_quantile   TSV            svr
# 1              log  all_features       all_features_log   TSV            svr
# 25             log  by_component       by_component_log   TSV            svr
# 145         minmax  all_features    all_features_minmax   TSV            svr
# 169         minmax  by_component    by_component_minmax   TSV            svr
# 193         minmax        s_only          s_only_minmax   TSV            svr
# 409         robust        s_only          s_only_robust   TSV            svr
# 49             log        s_only             s_only_log   TSV            svr
# 121          log1p        s_only           s_only_log1p   TSV            svr
# 73           log1p  all_features     all_features_log1p   TSV            svr
# 97           log1p  by_component     by_component_log1p   TSV            svr
# 265          power        s_only           s_only_power   TSV            svr
# 291       quantile  all_features  all_features_quantile   TSV            gbm
# 315       quantile  by_component  by_component_quantile   TSV            gbm
# 3              log  all_features       all_features_log   TSV            gbm
# 27             log  by_component       by_component_log   TSV            gbm
# 51             log        s_only             s_only_log   TSV            gbm
# 75           log1p  all_features     all_features_log1p   TSV            gbm
# 99           log1p  by_component     by_component_log1p   TSV            gbm
# 123          log1p        s_only           s_only_log1p   TSV            gbm
# 147         minmax  all_features    all_features_minmax   TSV            gbm
# 171         minmax  by_component    by_component_minmax   TSV            gbm
# 195         minmax        s_only          s_only_minmax   TSV            gbm
# 219          power  all_features     all_features_power   TSV            gbm
# 243          power  by_component     by_component_power   TSV            gbm
# 267          power        s_only           s_only_power   TSV            gbm
# 363         robust  all_features    all_features_robust   TSV            gbm
# 387         robust  by_component    by_component_robust   TSV            gbm
# 411         robust        s_only          s_only_robust   TSV            gbm
# 435       standard  all_features  all_features_standard   TSV            gbm
# 459       standard  by_component  by_component_standard   TSV            gbm
# 483       standard        s_only        s_only_standard   TSV            gbm
# 339       quantile        s_only        s_only_quantile   TSV            gbm
# 481       standard        s_only        s_only_standard   TSV            svr
# 337       quantile        s_only        s_only_quantile   TSV            svr
# 338       quantile        s_only        s_only_quantile   TSV  random_forest
# 146         minmax  all_features    all_features_minmax   TSV  random_forest
# 170         minmax  by_component    by_component_minmax   TSV  random_forest
# 194         minmax        s_only          s_only_minmax   TSV  random_forest
# 362         robust  all_features    all_features_robust   TSV  random_forest
# 386         robust  by_component    by_component_robust   TSV  random_forest
# 410         robust        s_only          s_only_robust   TSV  random_forest
# 434       standard  all_features  all_features_standard   TSV  random_forest
# 458       standard  by_component  by_component_standard   TSV  random_forest
# 482       standard        s_only        s_only_standard   TSV  random_forest
# 98           log1p  by_component     by_component_log1p   TSV  random_forest
# 2              log  all_features       all_features_log   TSV  random_forest
# 74           log1p  all_features     all_features_log1p   TSV  random_forest
# 122          log1p        s_only           s_only_log1p   TSV  random_forest
# 266          power        s_only           s_only_power   TSV  random_forest
# 50             log        s_only             s_only_log   TSV  random_forest
# 26             log  by_component       by_component_log   TSV  random_forest
# 218          power  all_features     all_features_power   TSV  random_forest
# 242          power  by_component     by_component_power   TSV  random_forest
# 290       quantile  all_features  all_features_quantile   TSV  random_forest
# 314       quantile  by_component  by_component_quantile   TSV  random_forest
# 225          power  all_features     all_features_power    SR            svr
# 249          power  by_component     by_component_power    SR            svr
# 441       standard  all_features  all_features_standard    SR            svr
# 465       standard  by_component  by_component_standard    SR            svr
# 369         robust  all_features    all_features_robust    SR            svr
# 393         robust  by_component    by_component_robust    SR            svr
# 9              log  all_features       all_features_log    SR            svr
# 297       quantile  all_features  all_features_quantile    SR            svr
# 321       quantile  by_component  by_component_quantile    SR            svr
# 33             log  by_component       by_component_log    SR            svr
# 153         minmax  all_features    all_features_minmax    SR            svr
# 177         minmax  by_component    by_component_minmax    SR            svr
# 201         minmax        s_only          s_only_minmax    SR            svr
# 129          log1p        s_only           s_only_log1p    SR            svr
# 57             log        s_only             s_only_log    SR            svr
# 489       standard        s_only        s_only_standard    SR            svr
# 417         robust        s_only          s_only_robust    SR            svr
# 81           log1p  all_features     all_features_log1p    SR            svr
# 105          log1p  by_component     by_component_log1p    SR            svr
# 347       quantile        s_only        s_only_quantile    SR            gbm
# 11             log  all_features       all_features_log    SR            gbm
# 35             log  by_component       by_component_log    SR            gbm
# 59             log        s_only             s_only_log    SR            gbm
# 83           log1p  all_features     all_features_log1p    SR            gbm
# 107          log1p  by_component     by_component_log1p    SR            gbm
# 131          log1p        s_only           s_only_log1p    SR            gbm
# 155         minmax  all_features    all_features_minmax    SR            gbm
# 179         minmax  by_component    by_component_minmax    SR            gbm
# 203         minmax        s_only          s_only_minmax    SR            gbm
# 227          power  all_features     all_features_power    SR            gbm
# 251          power  by_component     by_component_power    SR            gbm
# 275          power        s_only           s_only_power    SR            gbm
# 371         robust  all_features    all_features_robust    SR            gbm
# 395         robust  by_component    by_component_robust    SR            gbm
# 419         robust        s_only          s_only_robust    SR            gbm
# 443       standard  all_features  all_features_standard    SR            gbm
# 467       standard  by_component  by_component_standard    SR            gbm
# 491       standard        s_only        s_only_standard    SR            gbm
# 299       quantile  all_features  all_features_quantile    SR            gbm
# 323       quantile  by_component  by_component_quantile    SR            gbm
# 273          power        s_only           s_only_power    SR            svr
# 345       quantile        s_only        s_only_quantile    SR            svr
# 346       quantile        s_only        s_only_quantile    SR  random_forest
# 226          power  all_features     all_features_power    SR  random_forest
# 250          power  by_component     by_component_power    SR  random_forest
# 34             log  by_component       by_component_log    SR  random_forest
# 10             log  all_features       all_features_log    SR  random_forest
# 58             log        s_only             s_only_log    SR  random_forest
# 130          log1p        s_only           s_only_log1p    SR  random_forest
# 274          power        s_only           s_only_power    SR  random_forest
# 82           log1p  all_features     all_features_log1p    SR  random_forest
# 106          log1p  by_component     by_component_log1p    SR  random_forest
# 154         minmax  all_features    all_features_minmax    SR  random_forest
# 178         minmax  by_component    by_component_minmax    SR  random_forest
# 202         minmax        s_only          s_only_minmax    SR  random_forest
# 370         robust  all_features    all_features_robust    SR  random_forest
# 394         robust  by_component    by_component_robust    SR  random_forest
# 418         robust        s_only          s_only_robust    SR  random_forest
# 442       standard  all_features  all_features_standard    SR  random_forest
# 466       standard  by_component  by_component_standard    SR  random_forest
# 490       standard        s_only        s_only_standard    SR  random_forest
# 298       quantile  all_features  all_features_quantile    SR  random_forest
# 322       quantile  by_component  by_component_quantile    SR  random_forest
# 229          power  all_features     all_features_power     S            svr
# 253          power  by_component     by_component_power     S            svr
# 445       standard  all_features  all_features_standard     S            svr
# 469       standard  by_component  by_component_standard     S            svr
# 373         robust  all_features    all_features_robust     S            svr
# 397         robust  by_component    by_component_robust     S            svr
# 301       quantile  all_features  all_features_quantile     S            svr
# 325       quantile  by_component  by_component_quantile     S            svr
# 277          power        s_only           s_only_power     S            svr
# 13             log  all_features       all_features_log     S            svr
# 37             log  by_component       by_component_log     S            svr
# 157         minmax  all_features    all_features_minmax     S            svr
# 181         minmax  by_component    by_component_minmax     S            svr
# 205         minmax        s_only          s_only_minmax     S            svr
# 493       standard        s_only        s_only_standard     S            svr
# 61             log        s_only             s_only_log     S            svr
# 421         robust        s_only          s_only_robust     S            svr
# 133          log1p        s_only           s_only_log1p     S            svr
# 85           log1p  all_features     all_features_log1p     S            svr
# 109          log1p  by_component     by_component_log1p     S            svr
# 303       quantile  all_features  all_features_quantile     S            gbm
# 327       quantile  by_component  by_component_quantile     S            gbm
# 15             log  all_features       all_features_log     S            gbm
# 39             log  by_component       by_component_log     S            gbm
# 63             log        s_only             s_only_log     S            gbm
# 87           log1p  all_features     all_features_log1p     S            gbm
# 111          log1p  by_component     by_component_log1p     S            gbm
# 135          log1p        s_only           s_only_log1p     S            gbm
# 159         minmax  all_features    all_features_minmax     S            gbm
# 183         minmax  by_component    by_component_minmax     S            gbm
# 207         minmax        s_only          s_only_minmax     S            gbm
# 231          power  all_features     all_features_power     S            gbm
# 255          power  by_component     by_component_power     S            gbm
# 279          power        s_only           s_only_power     S            gbm
# 351       quantile        s_only        s_only_quantile     S            gbm
# 375         robust  all_features    all_features_robust     S            gbm
# 399         robust  by_component    by_component_robust     S            gbm
# 423         robust        s_only          s_only_robust     S            gbm
# 447       standard  all_features  all_features_standard     S            gbm
# 471       standard  by_component  by_component_standard     S            gbm
# 495       standard        s_only        s_only_standard     S            gbm
# 349       quantile        s_only        s_only_quantile     S            svr
# 230          power  all_features     all_features_power     S  random_forest
# 254          power  by_component     by_component_power     S  random_forest
# 86           log1p  all_features     all_features_log1p     S  random_forest
# 110          log1p  by_component     by_component_log1p     S  random_forest
# 14             log  all_features       all_features_log     S  random_forest
# 38             log  by_component       by_component_log     S  random_forest
# 134          log1p        s_only           s_only_log1p     S  random_forest
# 62             log        s_only             s_only_log     S  random_forest
# 278          power        s_only           s_only_power     S  random_forest
# 158         minmax  all_features    all_features_minmax     S  random_forest
# 182         minmax  by_component    by_component_minmax     S  random_forest
# 206         minmax        s_only          s_only_minmax     S  random_forest
# 374         robust  all_features    all_features_robust     S  random_forest
# 398         robust  by_component    by_component_robust     S  random_forest
# 422         robust        s_only          s_only_robust     S  random_forest
# 446       standard  all_features  all_features_standard     S  random_forest
# 470       standard  by_component  by_component_standard     S  random_forest
# 494       standard        s_only        s_only_standard     S  random_forest
# 350       quantile        s_only        s_only_quantile     S  random_forest
# 302       quantile  all_features  all_features_quantile     S  random_forest
# 326       quantile  by_component  by_component_quantile     S  random_forest
# 237          power  all_features     all_features_power     O            svr
# 261          power  by_component     by_component_power     O            svr
# 381         robust  all_features    all_features_robust     O            svr
# 405         robust  by_component    by_component_robust     O            svr
# 453       standard  all_features  all_features_standard     O            svr
# 477       standard  by_component  by_component_standard     O            svr
# 309       quantile  all_features  all_features_quantile     O            svr
# 333       quantile  by_component  by_component_quantile     O            svr
# 21             log  all_features       all_features_log     O            svr
# 429         robust        s_only          s_only_robust     O            svr
# 501       standard        s_only        s_only_standard     O            svr
# 45             log  by_component       by_component_log     O            svr
# 285          power        s_only           s_only_power     O            svr
# 165         minmax  all_features    all_features_minmax     O            svr
# 189         minmax  by_component    by_component_minmax     O            svr
# 311       quantile  all_features  all_features_quantile     O            gbm
# 335       quantile  by_component  by_component_quantile     O            gbm
# 359       quantile        s_only        s_only_quantile     O            gbm
# 47             log  by_component       by_component_log     O            gbm
# 71             log        s_only             s_only_log     O            gbm
# 95           log1p  all_features     all_features_log1p     O            gbm
# 119          log1p  by_component     by_component_log1p     O            gbm
# 143          log1p        s_only           s_only_log1p     O            gbm
# 167         minmax  all_features    all_features_minmax     O            gbm
# 191         minmax  by_component    by_component_minmax     O            gbm
# 215         minmax        s_only          s_only_minmax     O            gbm
# 287          power        s_only           s_only_power     O            gbm
# 383         robust  all_features    all_features_robust     O            gbm
# 407         robust  by_component    by_component_robust     O            gbm
# 431         robust        s_only          s_only_robust     O            gbm
# 455       standard  all_features  all_features_standard     O            gbm
# 479       standard  by_component  by_component_standard     O            gbm
# 503       standard        s_only        s_only_standard     O            gbm
# 23             log  all_features       all_features_log     O            gbm
# 239          power  all_features     all_features_power     O            gbm
# 263          power  by_component     by_component_power     O            gbm
# 213         minmax        s_only          s_only_minmax     O            svr
# 69             log        s_only             s_only_log     O            svr
# 117          log1p  by_component     by_component_log1p     O            svr
# 93           log1p  all_features     all_features_log1p     O            svr
# 141          log1p        s_only           s_only_log1p     O            svr
# 357       quantile        s_only        s_only_quantile     O            svr
# 94           log1p  all_features     all_features_log1p     O  random_forest
# 358       quantile        s_only        s_only_quantile     O  random_forest
# 286          power        s_only           s_only_power     O  random_forest
# 166         minmax  all_features    all_features_minmax     O  random_forest
# 190         minmax  by_component    by_component_minmax     O  random_forest
# 214         minmax        s_only          s_only_minmax     O  random_forest
# 430         robust        s_only          s_only_robust     O  random_forest
# 502       standard        s_only        s_only_standard     O  random_forest
# 382         robust  all_features    all_features_robust     O  random_forest
# 406         robust  by_component    by_component_robust     O  random_forest
# 454       standard  all_features  all_features_standard     O  random_forest
# 478       standard  by_component  by_component_standard     O  random_forest
# 238          power  all_features     all_features_power     O  random_forest
# 262          power  by_component     by_component_power     O  random_forest
# 118          log1p  by_component     by_component_log1p     O  random_forest
# 142          log1p        s_only           s_only_log1p     O  random_forest
# 70             log        s_only             s_only_log     O  random_forest
# 22             log  all_features       all_features_log     O  random_forest
# 46             log  by_component       by_component_log     O  random_forest
# 310       quantile  all_features  all_features_quantile     O  random_forest
# 334       quantile  by_component  by_component_quantile     O  random_forest
# 221          power  all_features     all_features_power     B            svr
# 245          power  by_component     by_component_power     B            svr
# 365         robust  all_features    all_features_robust     B            svr
# 389         robust  by_component    by_component_robust     B            svr
# 293       quantile  all_features  all_features_quantile     B            svr
# 317       quantile  by_component  by_component_quantile     B            svr
# 437       standard  all_features  all_features_standard     B            svr
# 461       standard  by_component  by_component_standard     B            svr
# 5              log  all_features       all_features_log     B            svr
# 295       quantile  all_features  all_features_quantile     B            gbm
# 319       quantile  by_component  by_component_quantile     B            gbm
# 7              log  all_features       all_features_log     B            gbm
# 31             log  by_component       by_component_log     B            gbm
# 55             log        s_only             s_only_log     B            gbm
# 79           log1p  all_features     all_features_log1p     B            gbm
# 103          log1p  by_component     by_component_log1p     B            gbm
# 127          log1p        s_only           s_only_log1p     B            gbm
# 151         minmax  all_features    all_features_minmax     B            gbm
# 175         minmax  by_component    by_component_minmax     B            gbm
# 199         minmax        s_only          s_only_minmax     B            gbm
# 223          power  all_features     all_features_power     B            gbm
# 247          power  by_component     by_component_power     B            gbm
# 271          power        s_only           s_only_power     B            gbm
# 367         robust  all_features    all_features_robust     B            gbm
# 391         robust  by_component    by_component_robust     B            gbm
# 415         robust        s_only          s_only_robust     B            gbm
# 439       standard  all_features  all_features_standard     B            gbm
# 463       standard  by_component  by_component_standard     B            gbm
# 487       standard        s_only        s_only_standard     B            gbm
# 343       quantile        s_only        s_only_quantile     B            gbm
# 29             log  by_component       by_component_log     B            svr
# 269          power        s_only           s_only_power     B            svr
# 485       standard        s_only        s_only_standard     B            svr
# 413         robust        s_only          s_only_robust     B            svr
# 149         minmax  all_features    all_features_minmax     B            svr
# 173         minmax  by_component    by_component_minmax     B            svr
# 125          log1p        s_only           s_only_log1p     B            svr
# 53             log        s_only             s_only_log     B            svr
# 77           log1p  all_features     all_features_log1p     B            svr
# 341       quantile        s_only        s_only_quantile     B            svr
# 101          log1p  by_component     by_component_log1p     B            svr
# 197         minmax        s_only          s_only_minmax     B            svr
# 150         minmax  all_features    all_features_minmax     B  random_forest
# 174         minmax  by_component    by_component_minmax     B  random_forest
# 366         robust  all_features    all_features_robust     B  random_forest
# 390         robust  by_component    by_component_robust     B  random_forest
# 438       standard  all_features  all_features_standard     B  random_forest
# 462       standard  by_component  by_component_standard     B  random_forest
# 198         minmax        s_only          s_only_minmax     B  random_forest
# 414         robust        s_only          s_only_robust     B  random_forest
# 486       standard        s_only        s_only_standard     B  random_forest
# 30             log  by_component       by_component_log     B  random_forest
# 270          power        s_only           s_only_power     B  random_forest
# 6              log  all_features       all_features_log     B  random_forest
# 54             log        s_only             s_only_log     B  random_forest
# 78           log1p  all_features     all_features_log1p     B  random_forest
# 102          log1p  by_component     by_component_log1p     B  random_forest
# 126          log1p        s_only           s_only_log1p     B  random_forest
# 222          power  all_features     all_features_power     B  random_forest
# 246          power  by_component     by_component_power     B  random_forest
# 294       quantile  all_features  all_features_quantile     B  random_forest
# 318       quantile  by_component  by_component_quantile     B  random_forest
# 342       quantile        s_only        s_only_quantile     B  random_forest
#
#      train_samples  test_samples      PLCC      SRCC      KRCC      RMSE
# 377            800           200  0.852790  0.851481  0.656104  0.416279
# 401            800           200  0.852790  0.851481  0.656104  0.416279
# 449            800           200  0.851002  0.850417  0.655199  0.422978
# 473            800           200  0.851002  0.850417  0.655199  0.422978
# 233            800           200  0.850800  0.851958  0.656205  0.421699
# 257            800           200  0.850800  0.851958  0.656205  0.421699
# 305            800           200  0.847024  0.854956  0.659726  0.422064
# 329            800           200  0.847024  0.854956  0.659726  0.422064
# 161            800           200  0.817773  0.822204  0.628540  0.449713
# 185            800           200  0.817773  0.822204  0.628540  0.449713
# 281            800           200  0.817408  0.820955  0.621800  0.449958
# 425            800           200  0.816030  0.816484  0.617977  0.452045
# 497            800           200  0.810007  0.807475  0.610634  0.457646
# 17             800           200  0.807111  0.811354  0.611841  0.462901
# 209            800           200  0.800347  0.802160  0.603089  0.468246
# 41             800           200  0.797631  0.799914  0.599869  0.472271
# 307            800           200  0.785080  0.792152  0.594337  0.488889
# 331            800           200  0.785080  0.792152  0.594337  0.488889
# 19             800           200  0.784053  0.790238  0.592626  0.489778
# 43             800           200  0.784053  0.790238  0.592626  0.489778
# 67             800           200  0.784053  0.790238  0.592626  0.489778
# 91             800           200  0.784053  0.790238  0.592626  0.489778
# 139            800           200  0.784053  0.790238  0.592626  0.489778
# 163            800           200  0.784053  0.790238  0.592626  0.489778
# 187            800           200  0.784053  0.790238  0.592626  0.489778
# 211            800           200  0.784053  0.790238  0.592626  0.489778
# 235            800           200  0.784053  0.790238  0.592626  0.489778
# 259            800           200  0.784053  0.790238  0.592626  0.489778
# 283            800           200  0.784053  0.790238  0.592626  0.489778
# 379            800           200  0.784053  0.790238  0.592626  0.489778
# 403            800           200  0.784053  0.790238  0.592626  0.489778
# 427            800           200  0.784053  0.790238  0.592626  0.489778
# 451            800           200  0.784053  0.790238  0.592626  0.489778
# 475            800           200  0.784053  0.790238  0.592626  0.489778
# 499            800           200  0.784053  0.790238  0.592626  0.489778
# 355            800           200  0.783892  0.790177  0.592828  0.489960
# 137            800           200  0.778868  0.774424  0.579750  0.490013
# 65             800           200  0.778691  0.780460  0.583070  0.490559
# 89             800           200  0.774525  0.769368  0.573915  0.494551
# 113            800           200  0.772961  0.767094  0.571501  0.496029
# 115            800           200  0.767365  0.769162  0.567376  0.504035
# 353            800           200  0.747192  0.752475  0.557517  0.518026
# 234            800           200  0.740202  0.731171  0.539510  0.528683
# 258            800           200  0.740202  0.731171  0.539510  0.528683
# 18             800           200  0.740095  0.731244  0.539309  0.528789
# 42             800           200  0.740094  0.731213  0.539410  0.528794
# 114            800           200  0.740092  0.730977  0.539410  0.528807
# 282            800           200  0.740071  0.730640  0.539108  0.528804
# 90             800           200  0.740049  0.730891  0.539309  0.528819
# 138            800           200  0.740016  0.730633  0.539209  0.528846
# 66             800           200  0.739932  0.730815  0.539309  0.528920
# 210            800           200  0.739915  0.730528  0.539007  0.528920
# 426            800           200  0.739915  0.730528  0.539007  0.528920
# 498            800           200  0.739915  0.730528  0.539007  0.528920
# 162            800           200  0.739912  0.730528  0.539007  0.528922
# 186            800           200  0.739912  0.730528  0.539007  0.528922
# 378            800           200  0.739912  0.730528  0.539007  0.528922
# 402            800           200  0.739912  0.730528  0.539007  0.528922
# 450            800           200  0.739912  0.730528  0.539007  0.528922
# 474            800           200  0.739912  0.730528  0.539007  0.528922
# 354            800           200  0.739889  0.731492  0.539611  0.529055
# 306            800           200  0.739714  0.731420  0.538907  0.529164
# 330            800           200  0.739714  0.731420  0.538907  0.529164
# 217            800           200  0.879489  0.857219  0.674380  0.315793
# 241            800           200  0.879489  0.857219  0.674380  0.315793
# 433            800           200  0.876421  0.853466  0.669551  0.319486
# 457            800           200  0.876421  0.853466  0.669551  0.319486
# 361            800           200  0.869470  0.843392  0.657278  0.327861
# 385            800           200  0.869470  0.843392  0.657278  0.327861
# 289            800           200  0.869365  0.851923  0.666935  0.327730
# 313            800           200  0.869365  0.851923  0.666935  0.327730
# 1              800           200  0.850150  0.829088  0.645507  0.351139
# 25             800           200  0.846935  0.826463  0.643093  0.354874
# 145            800           200  0.844201  0.822072  0.638163  0.365697
# 169            800           200  0.844201  0.822072  0.638163  0.365697
# 193            800           200  0.842756  0.819962  0.638264  0.361462
# 409            800           200  0.839475  0.812404  0.625488  0.366795
# 49             800           200  0.839383  0.812235  0.627399  0.363383
# 121            800           200  0.837035  0.813051  0.629009  0.366268
# 73             800           200  0.831705  0.802760  0.618446  0.372406
# 97             800           200  0.830644  0.800879  0.615629  0.373639
# 265            800           200  0.827160  0.781829  0.599834  0.379203
# 291            800           200  0.826503  0.794424  0.608989  0.373134
# 315            800           200  0.826503  0.794424  0.608989  0.373134
# 3              800           200  0.823303  0.792020  0.606977  0.377103
# 27             800           200  0.823303  0.792020  0.606977  0.377103
# 51             800           200  0.823303  0.792020  0.606977  0.377103
# 75             800           200  0.823303  0.792020  0.606977  0.377103
# 99             800           200  0.823303  0.792020  0.606977  0.377103
# 123            800           200  0.823303  0.792020  0.606977  0.377103
# 147            800           200  0.823303  0.792020  0.606977  0.377103
# 171            800           200  0.823303  0.792020  0.606977  0.377103
# 195            800           200  0.823303  0.792020  0.606977  0.377103
# 219            800           200  0.823303  0.792020  0.606977  0.377103
# 243            800           200  0.823303  0.792020  0.606977  0.377103
# 267            800           200  0.823303  0.792020  0.606977  0.377103
# 363            800           200  0.823303  0.792020  0.606977  0.377103
# 387            800           200  0.823303  0.792020  0.606977  0.377103
# 411            800           200  0.823303  0.792020  0.606977  0.377103
# 435            800           200  0.823303  0.792020  0.606977  0.377103
# 459            800           200  0.823303  0.792020  0.606977  0.377103
# 483            800           200  0.823303  0.792020  0.606977  0.377103
# 339            800           200  0.823276  0.797764  0.611001  0.377413
# 481            800           200  0.822822  0.778800  0.595810  0.382083
# 337            800           200  0.816201  0.777813  0.594301  0.390421
# 338            800           200  0.790900  0.759158  0.574382  0.406040
# 146            800           200  0.790858  0.759702  0.575589  0.406075
# 170            800           200  0.790858  0.759702  0.575589  0.406075
# 194            800           200  0.790858  0.759702  0.575589  0.406075
# 362            800           200  0.790858  0.759702  0.575589  0.406075
# 386            800           200  0.790858  0.759702  0.575589  0.406075
# 410            800           200  0.790858  0.759702  0.575589  0.406075
# 434            800           200  0.790858  0.759702  0.575589  0.406075
# 458            800           200  0.790858  0.759702  0.575589  0.406075
# 482            800           200  0.790858  0.759702  0.575589  0.406075
# 98             800           200  0.790842  0.759866  0.575791  0.406089
# 2              800           200  0.790842  0.759651  0.575489  0.406091
# 74             800           200  0.790837  0.759702  0.575589  0.406093
# 122            800           200  0.790836  0.759702  0.575589  0.406094
# 266            800           200  0.790835  0.759702  0.575589  0.406095
# 50             800           200  0.790834  0.759651  0.575489  0.406096
# 26             800           200  0.790827  0.759651  0.575489  0.406103
# 218            800           200  0.790792  0.759544  0.575288  0.406136
# 242            800           200  0.790792  0.759544  0.575288  0.406136
# 290            800           200  0.790527  0.759152  0.574483  0.406387
# 314            800           200  0.790527  0.759152  0.574483  0.406387
# 225            800           200  0.760139  0.767835  0.576714  0.442644
# 249            800           200  0.760139  0.767835  0.576714  0.442644
# 441            800           200  0.746339  0.749738  0.562940  0.452892
# 465            800           200  0.746339  0.749738  0.562940  0.452892
# 369            800           200  0.738656  0.746473  0.554896  0.458422
# 393            800           200  0.738656  0.746473  0.554896  0.458422
# 9              800           200  0.738602  0.749898  0.556103  0.458139
# 297            800           200  0.737902  0.744856  0.558013  0.459621
# 321            800           200  0.737902  0.744856  0.558013  0.459621
# 33             800           200  0.730389  0.738769  0.546954  0.464904
# 153            800           200  0.729382  0.727350  0.545043  0.471985
# 177            800           200  0.729382  0.727350  0.545043  0.471985
# 201            800           200  0.715527  0.726961  0.530163  0.474495
# 129            800           200  0.710257  0.715283  0.523929  0.479766
# 57             800           200  0.704234  0.709545  0.520712  0.483223
# 489            800           200  0.699988  0.699531  0.511864  0.493481
# 417            800           200  0.698602  0.696340  0.510255  0.492532
# 81             800           200  0.695090  0.694326  0.509351  0.489987
# 105            800           200  0.683914  0.697509  0.503117  0.511751
# 347            800           200  0.674782  0.640381  0.458979  0.503675
# 11             800           200  0.674440  0.640262  0.458777  0.503860
# 35             800           200  0.674440  0.640262  0.458777  0.503860
# 59             800           200  0.674440  0.640262  0.458777  0.503860
# 83             800           200  0.674440  0.640262  0.458777  0.503860
# 107            800           200  0.674440  0.640262  0.458777  0.503860
# 131            800           200  0.674440  0.640262  0.458777  0.503860
# 155            800           200  0.674440  0.640262  0.458777  0.503860
# 179            800           200  0.674440  0.640262  0.458777  0.503860
# 203            800           200  0.674440  0.640262  0.458777  0.503860
# 227            800           200  0.674440  0.640262  0.458777  0.503860
# 251            800           200  0.674440  0.640262  0.458777  0.503860
# 275            800           200  0.674440  0.640262  0.458777  0.503860
# 371            800           200  0.674440  0.640262  0.458777  0.503860
# 395            800           200  0.674440  0.640262  0.458777  0.503860
# 419            800           200  0.674440  0.640262  0.458777  0.503860
# 443            800           200  0.674440  0.640262  0.458777  0.503860
# 467            800           200  0.674440  0.640262  0.458777  0.503860
# 491            800           200  0.674440  0.640262  0.458777  0.503860
# 299            800           200  0.673026  0.640577  0.460185  0.504858
# 323            800           200  0.673026  0.640577  0.460185  0.504858
# 273            800           200  0.660225  0.646022  0.473658  0.510151
# 345            800           200  0.638344  0.646299  0.475065  0.523821
# 346            800           200  0.637373  0.624745  0.448422  0.535054
# 226            800           200  0.637251  0.624018  0.447919  0.535085
# 250            800           200  0.637251  0.624018  0.447919  0.535085
# 34             800           200  0.637199  0.623652  0.447818  0.535083
# 10             800           200  0.637166  0.623652  0.447818  0.535095
# 58             800           200  0.637151  0.623503  0.447617  0.535108
# 130            800           200  0.637142  0.623503  0.447617  0.535111
# 274            800           200  0.637109  0.623598  0.447718  0.535149
# 82             800           200  0.637109  0.623565  0.447718  0.535126
# 106            800           200  0.637109  0.623565  0.447718  0.535126
# 154            800           200  0.637053  0.623637  0.447617  0.535144
# 178            800           200  0.637053  0.623637  0.447617  0.535144
# 202            800           200  0.637053  0.623637  0.447617  0.535144
# 370            800           200  0.637017  0.623598  0.447718  0.535177
# 394            800           200  0.637017  0.623598  0.447718  0.535177
# 418            800           200  0.637017  0.623598  0.447718  0.535177
# 442            800           200  0.637017  0.623598  0.447718  0.535177
# 466            800           200  0.637017  0.623598  0.447718  0.535177
# 490            800           200  0.637017  0.623598  0.447718  0.535177
# 298            800           200  0.636749  0.625397  0.448723  0.535411
# 322            800           200  0.636749  0.625397  0.448723  0.535411
# 229            800           200  0.885383  0.879181  0.693100  0.366669
# 253            800           200  0.885383  0.879181  0.693100  0.366669
# 445            800           200  0.877635  0.870889  0.682446  0.377952
# 469            800           200  0.877635  0.870889  0.682446  0.377952
# 373            800           200  0.877537  0.869105  0.678426  0.380502
# 397            800           200  0.877537  0.869105  0.678426  0.380502
# 301            800           200  0.875895  0.870542  0.681140  0.380197
# 325            800           200  0.875895  0.870542  0.681140  0.380197
# 277            800           200  0.841491  0.837429  0.648475  0.426218
# 13             800           200  0.838559  0.841386  0.643851  0.427107
# 37             800           200  0.832316  0.832642  0.632193  0.434310
# 157            800           200  0.828106  0.835099  0.632796  0.442334
# 181            800           200  0.828106  0.835099  0.632796  0.442334
# 205            800           200  0.827568  0.829109  0.634906  0.442202
# 493            800           200  0.821978  0.824495  0.634504  0.453863
# 61             800           200  0.819719  0.820418  0.620232  0.448846
# 421            800           200  0.817508  0.821310  0.626665  0.457244
# 133            800           200  0.815605  0.812930  0.610985  0.453678
# 85             800           200  0.807940  0.804384  0.601839  0.462125
# 109            800           200  0.806123  0.802499  0.600131  0.464088
# 303            800           200  0.795617  0.792166  0.592090  0.474724
# 327            800           200  0.795617  0.792166  0.592090  0.474724
# 15             800           200  0.795071  0.792435  0.592693  0.475280
# 39             800           200  0.795071  0.792435  0.592693  0.475280
# 63             800           200  0.795071  0.792435  0.592693  0.475280
# 87             800           200  0.795071  0.792435  0.592693  0.475280
# 111            800           200  0.795071  0.792435  0.592693  0.475280
# 135            800           200  0.795071  0.792435  0.592693  0.475280
# 159            800           200  0.795071  0.792435  0.592693  0.475280
# 183            800           200  0.795071  0.792435  0.592693  0.475280
# 207            800           200  0.795071  0.792435  0.592693  0.475280
# 231            800           200  0.795071  0.792435  0.592693  0.475280
# 255            800           200  0.795071  0.792435  0.592693  0.475280
# 279            800           200  0.795071  0.792435  0.592693  0.475280
# 351            800           200  0.795071  0.792435  0.592693  0.475280
# 375            800           200  0.795071  0.792435  0.592693  0.475280
# 399            800           200  0.795071  0.792435  0.592693  0.475280
# 423            800           200  0.795071  0.792435  0.592693  0.475280
# 447            800           200  0.795071  0.792435  0.592693  0.475280
# 471            800           200  0.795071  0.792435  0.592693  0.475280
# 495            800           200  0.795071  0.792435  0.592693  0.475280
# 349            800           200  0.784578  0.771982  0.581235  0.490411
# 230            800           200  0.774301  0.770031  0.568169  0.495863
# 254            800           200  0.774301  0.770031  0.568169  0.495863
# 86             800           200  0.774247  0.770121  0.568370  0.495908
# 110            800           200  0.774247  0.770121  0.568370  0.495908
# 14             800           200  0.774240  0.770034  0.568169  0.495917
# 38             800           200  0.774225  0.770034  0.568169  0.495931
# 134            800           200  0.774214  0.770298  0.568672  0.495938
# 62             800           200  0.774212  0.770298  0.568672  0.495940
# 278            800           200  0.774203  0.770298  0.568672  0.495947
# 158            800           200  0.774177  0.770298  0.568571  0.495975
# 182            800           200  0.774177  0.770298  0.568571  0.495975
# 206            800           200  0.774177  0.770298  0.568571  0.495975
# 374            800           200  0.774177  0.770298  0.568571  0.495975
# 398            800           200  0.774177  0.770298  0.568571  0.495975
# 422            800           200  0.774177  0.770298  0.568571  0.495975
# 446            800           200  0.774177  0.770298  0.568571  0.495975
# 470            800           200  0.774177  0.770298  0.568571  0.495975
# 494            800           200  0.774177  0.770298  0.568571  0.495975
# 350            800           200  0.774043  0.770304  0.567968  0.496106
# 302            800           200  0.773226  0.768423  0.566762  0.496879
# 326            800           200  0.773226  0.768423  0.566762  0.496879
# 237            800           200  0.873969  0.867528  0.681785  0.528467
# 261            800           200  0.873969  0.867528  0.681785  0.528467
# 381            800           200  0.871954  0.866259  0.677863  0.533142
# 405            800           200  0.871954  0.866259  0.677863  0.533142
# 453            800           200  0.870478  0.867480  0.680679  0.535005
# 477            800           200  0.870478  0.867480  0.680679  0.535005
# 309            800           200  0.864687  0.861375  0.671226  0.546748
# 333            800           200  0.864687  0.861375  0.671226  0.546748
# 21             800           200  0.840469  0.837277  0.648096  0.585204
# 429            800           200  0.836970  0.836236  0.651515  0.592216
# 501            800           200  0.836945  0.834344  0.646788  0.592764
# 45             800           200  0.832213  0.829343  0.639447  0.598922
# 285            800           200  0.831591  0.829040  0.640754  0.600762
# 165            800           200  0.830147  0.830845  0.642162  0.605034
# 189            800           200  0.830147  0.830845  0.642162  0.605034
# 311            800           200  0.828927  0.819960  0.631703  0.605789
# 335            800           200  0.828927  0.819960  0.631703  0.605789
# 359            800           200  0.828821  0.820380  0.632005  0.606081
# 47             800           200  0.828618  0.820305  0.631804  0.606355
# 71             800           200  0.828618  0.820305  0.631804  0.606355
# 95             800           200  0.828618  0.820305  0.631804  0.606355
# 119            800           200  0.828618  0.820305  0.631804  0.606355
# 143            800           200  0.828618  0.820305  0.631804  0.606355
# 167            800           200  0.828618  0.820305  0.631804  0.606355
# 191            800           200  0.828618  0.820305  0.631804  0.606355
# 215            800           200  0.828618  0.820305  0.631804  0.606355
# 287            800           200  0.828618  0.820305  0.631804  0.606355
# 383            800           200  0.828618  0.820305  0.631804  0.606355
# 407            800           200  0.828618  0.820305  0.631804  0.606355
# 431            800           200  0.828618  0.820305  0.631804  0.606355
# 455            800           200  0.828618  0.820305  0.631804  0.606355
# 479            800           200  0.828618  0.820305  0.631804  0.606355
# 503            800           200  0.828618  0.820305  0.631804  0.606355
# 23             800           200  0.828512  0.820137  0.631402  0.606524
# 239            800           200  0.828512  0.820137  0.631402  0.606524
# 263            800           200  0.828512  0.820137  0.631402  0.606524
# 213            800           200  0.825821  0.827486  0.638341  0.608870
# 69             800           200  0.818880  0.815279  0.624362  0.619744
# 117            800           200  0.816912  0.826904  0.635626  0.630451
# 93             800           200  0.814975  0.825879  0.633614  0.634410
# 141            800           200  0.814859  0.810745  0.617725  0.626434
# 357            800           200  0.788671  0.783468  0.597712  0.664316
# 94             800           200  0.785497  0.778323  0.587756  0.673612
# 358            800           200  0.785326  0.778088  0.587756  0.673933
# 286            800           200  0.785152  0.777995  0.587857  0.674036
# 166            800           200  0.785125  0.777995  0.587857  0.674068
# 190            800           200  0.785125  0.777995  0.587857  0.674068
# 214            800           200  0.785125  0.777995  0.587857  0.674068
# 430            800           200  0.785125  0.777995  0.587857  0.674068
# 502            800           200  0.785125  0.777995  0.587857  0.674068
# 382            800           200  0.785121  0.777796  0.587656  0.674060
# 406            800           200  0.785121  0.777796  0.587656  0.674060
# 454            800           200  0.785121  0.777796  0.587656  0.674060
# 478            800           200  0.785121  0.777796  0.587656  0.674060
# 238            800           200  0.785117  0.777905  0.587756  0.674071
# 262            800           200  0.785117  0.777905  0.587756  0.674071
# 118            800           200  0.785099  0.778103  0.587957  0.674096
# 142            800           200  0.785097  0.777995  0.587857  0.674098
# 70             800           200  0.785090  0.777995  0.587857  0.674107
# 22             800           200  0.785060  0.778080  0.587756  0.674149
# 46             800           200  0.785054  0.778091  0.587857  0.674152
# 310            800           200  0.785025  0.777665  0.588058  0.674270
# 334            800           200  0.785025  0.777665  0.588058  0.674270
# 221            800           200  0.740516  0.723099  0.530265  0.551695
# 245            800           200  0.740516  0.723099  0.530265  0.551695
# 365            800           200  0.739844  0.714427  0.521899  0.550225
# 389            800           200  0.739844  0.714427  0.521899  0.550225
# 293            800           200  0.737727  0.720587  0.526132  0.555758
# 317            800           200  0.737727  0.720587  0.526132  0.555758
# 437            800           200  0.735476  0.714438  0.523713  0.554964
# 461            800           200  0.735476  0.714438  0.523713  0.554964
# 5              800           200  0.724466  0.706459  0.523411  0.560735
# 295            800           200  0.717721  0.666929  0.495088  0.568443
# 319            800           200  0.717721  0.666929  0.495088  0.568443
# 7              800           200  0.717471  0.667017  0.494282  0.568875
# 31             800           200  0.717471  0.667017  0.494282  0.568875
# 55             800           200  0.717471  0.667017  0.494282  0.568875
# 79             800           200  0.717471  0.667017  0.494282  0.568875
# 103            800           200  0.717471  0.667017  0.494282  0.568875
# 127            800           200  0.717471  0.667017  0.494282  0.568875
# 151            800           200  0.717471  0.667017  0.494282  0.568875
# 175            800           200  0.717471  0.667017  0.494282  0.568875
# 199            800           200  0.717471  0.667017  0.494282  0.568875
# 223            800           200  0.717471  0.667017  0.494282  0.568875
# 247            800           200  0.717471  0.667017  0.494282  0.568875
# 271            800           200  0.717471  0.667017  0.494282  0.568875
# 367            800           200  0.717471  0.667017  0.494282  0.568875
# 391            800           200  0.717471  0.667017  0.494282  0.568875
# 415            800           200  0.717471  0.667017  0.494282  0.568875
# 439            800           200  0.717471  0.667017  0.494282  0.568875
# 463            800           200  0.717471  0.667017  0.494282  0.568875
# 487            800           200  0.717471  0.667017  0.494282  0.568875
# 343            800           200  0.716763  0.666437  0.493476  0.569321
# 29             800           200  0.707758  0.692648  0.510610  0.574620
# 269            800           200  0.701038  0.664118  0.487932  0.582736
# 485            800           200  0.700415  0.662813  0.484001  0.584133
# 413            800           200  0.698451  0.663719  0.486622  0.585960
# 149            800           200  0.697387  0.664409  0.480877  0.583321
# 173            800           200  0.697387  0.664409  0.480877  0.583321
# 125            800           200  0.693131  0.677353  0.491258  0.585756
# 53             800           200  0.692759  0.671212  0.490150  0.586717
# 77             800           200  0.686302  0.662470  0.477551  0.591299
# 341            800           200  0.685141  0.651698  0.475333  0.596866
# 101            800           200  0.685132  0.660465  0.475938  0.592140
# 197            800           200  0.682291  0.660745  0.480171  0.594410
# 150            800           200  0.652943  0.604702  0.437637  0.622945
# 174            800           200  0.652943  0.604702  0.437637  0.622945
# 366            800           200  0.652943  0.604702  0.437637  0.622945
# 390            800           200  0.652943  0.604702  0.437637  0.622945
# 438            800           200  0.652943  0.604702  0.437637  0.622945
# 462            800           200  0.652943  0.604702  0.437637  0.622945
# 198            800           200  0.652918  0.604702  0.437637  0.622972
# 414            800           200  0.652918  0.604702  0.437637  0.622972
# 486            800           200  0.652918  0.604702  0.437637  0.622972
# 30             800           200  0.650720  0.603512  0.434916  0.622268
# 270            800           200  0.650705  0.603174  0.434613  0.622274
# 6              800           200  0.650694  0.603492  0.434916  0.622283
# 54             800           200  0.650688  0.603280  0.434815  0.622286
# 78             800           200  0.650688  0.603280  0.434815  0.622286
# 102            800           200  0.650688  0.603280  0.434815  0.622286
# 126            800           200  0.650688  0.603280  0.434815  0.622286
# 222            800           200  0.650675  0.603386  0.434714  0.622289
# 246            800           200  0.650675  0.603386  0.434714  0.622289
# 294            800           200  0.650552  0.602896  0.433001  0.622309
# 318            800           200  0.650552  0.602896  0.433001  0.622309
# 342            800           200  0.649452  0.601474  0.433001  0.622964
