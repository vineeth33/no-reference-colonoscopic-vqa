# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import os
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr, spearmanr, kendalltau
import warnings
warnings.filterwarnings('ignore')

# %%
class RegressionModelTrainer:
    """
    A comprehensive class for training multiple regression models on scaled feature datasets
    with hyperparameter tuning and performance evaluation.
    """
    
    def __init__(self, features_base_path, labels_path, models_save_path):
        """
        Initialize the trainer with paths and configuration.
        
        Args:
            features_base_path: Base path to scaled features directory
            labels_path: Path to the labels CSV file
            models_save_path: Base path to save trained models
        """
        self.features_base_path = features_base_path
        self.labels_path = labels_path
        self.models_save_path = models_save_path
        
        # Define scaling methods and dataset types
        self.scaling_methods = ['log', 'log1p', 'minmax', 'power', 'quantile', 'robust', 'standard']
        self.dataset_types = ['all_features', 'by_component', 's_only']
        self.labels = ['TSV', 'B', 'SR', 'S', 'U', 'O']
        
        # Define models and their hyperparameter grids
        self.models = {
            'linear_regression': {
                'model': LinearRegression,
                'params': {}  # Linear regression has no hyperparameters to tune
            },
            'svr': {
                'model': SVR,
                'params': {
                    'C': [0.1, 1, 10, 100],
                    'gamma': ['scale', 'auto', 0.001, 0.01, 0.1, 1],
                    'kernel': ['rbf', 'poly', 'sigmoid'],
                    'epsilon': [0.01, 0.1, 0.2]
                }
            },
            'random_forest': {
                'model': RandomForestRegressor,
                'params': {
                    'n_estimators': [50, 100, 200, 300],
                    'max_depth': [None, 10, 20, 30],
                    'min_samples_split': [2, 5, 10],
                    'min_samples_leaf': [1, 2, 4],
                    'max_features': ['auto', 'sqrt', 'log2']
                }
            },
            'gbm': {
                'model': GradientBoostingRegressor,
                'params': {
                    'n_estimators': [50, 100, 200],
                    'learning_rate': [0.01, 0.1, 0.2],
                    'max_depth': [3, 5, 7],
                    'min_samples_split': [2, 5, 10],
                    'min_samples_leaf': [1, 2, 4],
                    'subsample': [0.8, 0.9, 1.0]
                }
            }
        }
        
        # Create directories for saving models
        self._create_model_directories()
        
        # Load labels
        self.labels_df = self._load_labels()
        
        # Initialize results storage
        self.results = []
    
    def _create_model_directories(self):
        """Create directories for saving trained models."""
        for model_name in self.models.keys():
            model_dir = os.path.join(self.models_save_path, model_name)
            os.makedirs(model_dir, exist_ok=True)
    
    def _load_labels(self):
        """Load the labels CSV file."""
        try:
            labels_df = pd.read_csv(self.labels_path)
            print(f"Labels loaded successfully. Shape: {labels_df.shape}\n\n")
            return labels_df
        except Exception as e:
            print(f"Error loading labels: {e}\n\n")
            return None
    
    def _load_features(self, scaling_method, dataset_type):
        """
        Load features for a specific scaling method and dataset type.
        
        Args:
            scaling_method: The scaling method (e.g., 'log', 'minmax')
            dataset_type: The dataset type (e.g., 'all_features', 'by_component')
        
        Returns:
            pandas.DataFrame: Loaded features
        """
        filename = f"{dataset_type}_{scaling_method}.csv"
        filepath = os.path.join(self.features_base_path, scaling_method, filename)
        
        try:
            features_df = pd.read_csv(filepath)
            features_df = features_df.drop('videoname', axis=1)
            print(f"Features loaded: {filename}, Shape: {features_df.shape}\n\n")
            return features_df
        except Exception as e:
            print(f"Error loading {filename}: {e}\n\n")
            return None
    
    def _calculate_metrics(self, y_true, y_pred):
        """
        Calculate evaluation metrics: PLCC, SRCC, KRCC, RMSE.
        
        Args:
            y_true: True values
            y_pred: Predicted values
            
        Returns:
            dict: Dictionary containing all metrics
        """
        # Remove NaN values
        mask = ~(np.isnan(y_true) | np.isnan(y_pred))
        y_true_clean = y_true[mask]
        y_pred_clean = y_pred[mask]
        
        if len(y_true_clean) == 0:
            return {'PLCC': np.nan, 'SRCC': np.nan, 'KRCC': np.nan, 'RMSE': np.nan}
        
        # PLCC (Pearson Linear Correlation Coefficient)
        plcc, _ = pearsonr(y_true_clean, y_pred_clean)
        
        # SRCC (Spearman Rank Correlation Coefficient)
        srcc, _ = spearmanr(y_true_clean, y_pred_clean)
        
        # KRCC (Kendall Rank Correlation Coefficient)
        krcc, _ = kendalltau(y_true_clean, y_pred_clean)
        
        # RMSE (Root Mean Square Error)
        rmse = np.sqrt(mean_squared_error(y_true_clean, y_pred_clean))
        
        return {
            'PLCC': plcc,
            'SRCC': srcc,
            'KRCC': krcc,
            'RMSE': rmse
        }
    
    def _train_model(self, model_name, X_train, y_train, X_test, y_test):
        """
        Train a single model with hyperparameter tuning.
        
        Args:
            model_name: Name of the model to train
            X_train, y_train: Training data
            X_test, y_test: Testing data
            
        Returns:
            tuple: (trained_model, metrics_dict)
        """
        model_config = self.models[model_name]
        model_class = model_config['model']
        param_grid = model_config['params']
        
        print(f"    Training {model_name}...")
        
        if model_name == 'linear_regression':
            # No hyperparameter tuning needed for linear regression
            model = model_class()
            model.fit(X_train, y_train)
            best_model = model
        else:
            # Use RandomizedSearchCV for faster hyperparameter tuning
            if model_name == 'svr':
                model = model_class()
            else:
                model = model_class(random_state=42)
            
            # Adjust search strategy based on model complexity
            if model_name in ['svr', 'gbm']:
                search_cv = RandomizedSearchCV(
                    model, param_grid, n_iter=20, cv=3, 
                    scoring='neg_mean_squared_error', random_state=42, n_jobs=-1
                )
            else:
                search_cv = RandomizedSearchCV(
                    model, param_grid, n_iter=30, cv=3,
                    scoring='neg_mean_squared_error', random_state=42, n_jobs=-1
                )
            
            search_cv.fit(X_train, y_train)
            best_model = search_cv.best_estimator_
            print(f"      Best parameters: {search_cv.best_params_}")
        print("\n")
        # Make predictions
        y_pred = best_model.predict(X_test)
        
        # Calculate metrics
        metrics = self._calculate_metrics(y_test, y_pred)
        
        return best_model, metrics
    
    def _save_model(self, model, model_name, dataset_name, label_name):
        """
        Save a trained model to disk.
        
        Args:
            model: Trained model object
            model_name: Name of the model type
            dataset_name: Name of the dataset
            label_name: Name of the target label
        """
        model_dir = os.path.join(self.models_save_path, model_name)
        filename = f"{dataset_name}_{label_name}.pkl"
        filepath = os.path.join(model_dir, filename)
        
        try:
            with open(filepath, 'wb') as f:
                pickle.dump(model, f)
            print(f"      Model saved: {filepath}")
        except Exception as e:
            print(f"      Error saving model {filepath}: {e}")
        print("\n")
    
    def train_all_models(self, test_size=0.2, random_state=42):
        """
        Train all models on all datasets for all labels.
        
        Args:
            test_size: Proportion of data to use for testing
            random_state: Random seed for reproducibility
        """
        print("Starting comprehensive model training...")
        print(f"Total combinations: {len(self.scaling_methods)} scaling methods × "
              f"{len(self.dataset_types)} dataset types × {len(self.labels)} labels × "
              f"{len(self.models)} models = {len(self.scaling_methods) * len(self.dataset_types) * len(self.labels) * len(self.models)} models")
        
        total_models = 0
        successful_models = 0
        
        for scaling_method in self.scaling_methods:
            for dataset_type in self.dataset_types:
                dataset_name = f"{dataset_type}_{scaling_method}"
                print(f"\nProcessing dataset: {dataset_name}")
                
                # Load features
                features_df = self._load_features(scaling_method, dataset_type)
                if features_df is None:
                    print(f"  Skipping {dataset_name} due to loading error")
                    continue
                
                for label in self.labels:
                    print(f"  Target label: {label}")
                    
                    # Check if label exists in labels dataframe
                    if label not in self.labels_df.columns:
                        print(f"    Label {label} not found in labels file")
                        continue
                    
                    # Prepare data
                    y = self.labels_df[label].values
                    X = features_df.values
                    
                    # Check for matching dimensions
                    if len(X) != len(y):
                        print(f"    Dimension mismatch: Features={len(X)}, Labels={len(y)}")
                        continue
                    
                    # Remove samples with NaN values
                    mask = ~(np.isnan(y) | np.isnan(X).any(axis=1))
                    X_clean = X[mask]
                    y_clean = y[mask]
                    
                    if len(X_clean) == 0:
                        print(f"    No valid samples after cleaning")
                        continue
                    
                    # Split data
                    X_train, X_test, y_train, y_test = train_test_split(
                        X_clean, y_clean, test_size=test_size, random_state=random_state
                    )
                    
                    # Train each model
                    for model_name in self.models.keys():
                        total_models += 1
                        
                        try:
                            model, metrics = self._train_model(
                                model_name, X_train, y_train, X_test, y_test
                            )
                            
                            # Save model
                            self._save_model(model, model_name, dataset_name, label)
                            
                            # Store results
                            result = {
                                'scaling_method': scaling_method,
                                'dataset_type': dataset_type,
                                'dataset_name': dataset_name,
                                'label': label,
                                'model': model_name,
                                'train_samples': len(X_train),
                                'test_samples': len(X_test),
                                **metrics
                            }
                            self.results.append(result)
                            
                            successful_models += 1
                            
                            print(f"      ✓ {model_name} - PLCC: {metrics['PLCC']:.4f}, "
                                  f"SRCC: {metrics['SRCC']:.4f}, KRCC: {metrics['KRCC']:.4f}, "
                                  f"RMSE: {metrics['RMSE']:.4f}")
                            
                        except Exception as e:
                            print(f"      ✗ {model_name} failed: {e}")
        
        print(f"\nTraining completed!")
        print(f"Successfully trained: {successful_models}/{total_models} models\n\n")
        
        # Save results to CSV
        self.save_results()
    
    def save_results(self, filename="training_results.csv"):
        """Save all training results to a CSV file."""
        if self.results:
            results_df = pd.DataFrame(self.results)
            filepath = os.path.join(self.models_save_path, filename)
            results_df.to_csv(filepath, index=False)
            print(f"\nResults saved to: {filepath}")
            
            # Display summary statistics
            self.display_results_summary(results_df)
        else:
            print("No results to save.")

        print("\n")
    
    def display_results_summary(self, results_df):
        """Display summary statistics of the training results."""
        print("\n" + "="*80)
        print("TRAINING RESULTS SUMMARY")
        print("="*80)
        
        # Best models by metric
        metrics = ['PLCC', 'SRCC', 'KRCC', 'RMSE']
        
        for metric in metrics:
            print(f"\nBest {metric}:")
            if metric == 'RMSE':
                best_result = results_df.loc[results_df[metric].idxmin()]
                print(f"  {best_result['model']} on {best_result['dataset_name']} "
                      f"for {best_result['label']}: {best_result[metric]:.4f}")
            else:
                best_result = results_df.loc[results_df[metric].idxmax()]
                print(f"  {best_result['model']} on {best_result['dataset_name']} "
                      f"for {best_result['label']}: {best_result[metric]:.4f}")
        
        # Average performance by model
        print(f"\nAverage Performance by Model:")
        model_avg = results_df.groupby('model')[metrics].mean()
        for model in model_avg.index:
            print(f"  {model}:")
            for metric in metrics:
                print(f"    {metric}: {model_avg.loc[model, metric]:.4f}")
        
        # Average performance by dataset
        print(f"\nTop 5 Dataset Configurations (by PLCC):")
        dataset_avg = results_df.groupby(['dataset_name', 'label'])['PLCC'].mean().sort_values(ascending=False).head()
        for (dataset, label), plcc in dataset_avg.items():
            print(f"  {dataset} → {label}: {plcc:.4f}")
        print("\n")

# %%
def main():
    # Initialize the trainer
    trainer = RegressionModelTrainer(
        features_base_path="../preprocessing/scaling/scaled-features/",
        labels_path="../../dataset/cleaned/cleaned-mos.csv",
        models_save_path="./"
    )
    
    # Train all models
    trainer.train_all_models(test_size=0.2, random_state=42)
    
    print("\nAll models have been trained and saved!")

if __name__ == "__main__":
    main()
# Out:
# Labels loaded successfully. Shape: (1000, 7)
#
#
# Starting comprehensive model training...
# Total combinations: 7 scaling methods × 3 dataset types × 6 labels × 4 models = 504 models
#
# Processing dataset: all_features_log
# Features loaded: all_features_log.csv, Shape: (1000, 1152)
#
#
#   Target label: TSV
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_log_TSV.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5913, SRCC: 0.5889, KRCC: 0.4100, RMSE: 0.7316
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\all_features_log_TSV.pkl
#
#
#       ✓ svr - PLCC: 0.8502, SRCC: 0.8291, KRCC: 0.6455, RMSE: 0.3511
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
#
#
#       Model saved: ./random_forest\all_features_log_TSV.pkl
#
#
#       ✓ random_forest - PLCC: 0.7908, SRCC: 0.7597, KRCC: 0.5755, RMSE: 0.4061
#     Training gbm...
#       Best parameters: {'subsample': 0.8, 'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 5, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_log_TSV.pkl
#
#
#       ✓ gbm - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#   Target label: B
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_log_B.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4027, SRCC: 0.4337, KRCC: 0.2991, RMSE: 1.5137
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\all_features_log_B.pkl
#
#
#       ✓ svr - PLCC: 0.7245, SRCC: 0.7065, KRCC: 0.5234, RMSE: 0.5607
#     Training random_forest...
#       Best parameters: {'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
#
#
#       Model saved: ./random_forest\all_features_log_B.pkl
#
#
#       ✓ random_forest - PLCC: 0.6507, SRCC: 0.6035, KRCC: 0.4349, RMSE: 0.6223
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_log_B.pkl
#
#
#       ✓ gbm - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#   Target label: SR
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_log_SR.pkl
#
#
#       ✓ linear_regression - PLCC: 0.2882, SRCC: 0.2967, KRCC: 0.2025, RMSE: 1.1706
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\all_features_log_SR.pkl
#
#
#       ✓ svr - PLCC: 0.7386, SRCC: 0.7499, KRCC: 0.5561, RMSE: 0.4581
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\all_features_log_SR.pkl
#
#
#       ✓ random_forest - PLCC: 0.6372, SRCC: 0.6237, KRCC: 0.4478, RMSE: 0.5351
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_log_SR.pkl
#
#
#       ✓ gbm - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#   Target label: S
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_log_S.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5414, SRCC: 0.5696, KRCC: 0.3990, RMSE: 0.9704
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\all_features_log_S.pkl
#
#
#       ✓ svr - PLCC: 0.8386, SRCC: 0.8414, KRCC: 0.6439, RMSE: 0.4271
#     Training random_forest...
#       Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10}
#
#
#       Model saved: ./random_forest\all_features_log_S.pkl
#
#
#       ✓ random_forest - PLCC: 0.7742, SRCC: 0.7700, KRCC: 0.5682, RMSE: 0.4959
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_log_S.pkl
#
#
#       ✓ gbm - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#   Target label: U
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_log_U.pkl
#
#
#       ✓ linear_regression - PLCC: 0.3960, SRCC: 0.4313, KRCC: 0.3017, RMSE: 1.0575
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\all_features_log_U.pkl
#
#
#       ✓ svr - PLCC: 0.8071, SRCC: 0.8114, KRCC: 0.6118, RMSE: 0.4629
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None}
#
#
#       Model saved: ./random_forest\all_features_log_U.pkl
#
#
#       ✓ random_forest - PLCC: 0.7401, SRCC: 0.7312, KRCC: 0.5393, RMSE: 0.5288
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_log_U.pkl
#
#
#       ✓ gbm - PLCC: 0.7841, SRCC: 0.7902, KRCC: 0.5926, RMSE: 0.4898
#   Target label: O
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_log_O.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5407, SRCC: 0.5745, KRCC: 0.4128, RMSE: 1.2773
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\all_features_log_O.pkl
#
#
#       ✓ svr - PLCC: 0.8405, SRCC: 0.8373, KRCC: 0.6481, RMSE: 0.5852
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\all_features_log_O.pkl
#
#
#       ✓ random_forest - PLCC: 0.7851, SRCC: 0.7781, KRCC: 0.5878, RMSE: 0.6741
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_log_O.pkl
#
#
#       ✓ gbm - PLCC: 0.8285, SRCC: 0.8201, KRCC: 0.6314, RMSE: 0.6065
#
# Processing dataset: by_component_log
# Features loaded: by_component_log.csv, Shape: (1000, 1152)
#
#
#   Target label: TSV
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_log_TSV.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5954, SRCC: 0.6003, KRCC: 0.4193, RMSE: 0.7121
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\by_component_log_TSV.pkl
#
#
#       ✓ svr - PLCC: 0.8469, SRCC: 0.8265, KRCC: 0.6431, RMSE: 0.3549
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
#
#
#       Model saved: ./random_forest\by_component_log_TSV.pkl
#
#
#       ✓ random_forest - PLCC: 0.7908, SRCC: 0.7597, KRCC: 0.5755, RMSE: 0.4061
#     Training gbm...
#       Best parameters: {'subsample': 0.8, 'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 5, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_log_TSV.pkl
#
#
#       ✓ gbm - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#   Target label: B
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_log_B.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4206, SRCC: 0.4473, KRCC: 0.3073, RMSE: 1.4011
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\by_component_log_B.pkl
#
#
#       ✓ svr - PLCC: 0.7078, SRCC: 0.6926, KRCC: 0.5106, RMSE: 0.5746
#     Training random_forest...
#       Best parameters: {'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
#
#
#       Model saved: ./random_forest\by_component_log_B.pkl
#
#
#       ✓ random_forest - PLCC: 0.6507, SRCC: 0.6035, KRCC: 0.4349, RMSE: 0.6223
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_log_B.pkl
#
#
#       ✓ gbm - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#   Target label: SR
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_log_SR.pkl
#
#
#       ✓ linear_regression - PLCC: 0.2969, SRCC: 0.2932, KRCC: 0.1991, RMSE: 1.1265
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\by_component_log_SR.pkl
#
#
#       ✓ svr - PLCC: 0.7304, SRCC: 0.7388, KRCC: 0.5470, RMSE: 0.4649
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\by_component_log_SR.pkl
#
#
#       ✓ random_forest - PLCC: 0.6372, SRCC: 0.6237, KRCC: 0.4478, RMSE: 0.5351
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_log_SR.pkl
#
#
#       ✓ gbm - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#   Target label: S
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_log_S.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5413, SRCC: 0.5694, KRCC: 0.4010, RMSE: 0.9381
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\by_component_log_S.pkl
#
#
#       ✓ svr - PLCC: 0.8323, SRCC: 0.8326, KRCC: 0.6322, RMSE: 0.4343
#     Training random_forest...
#       Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10}
#
#
#       Model saved: ./random_forest\by_component_log_S.pkl
#
#
#       ✓ random_forest - PLCC: 0.7742, SRCC: 0.7700, KRCC: 0.5682, RMSE: 0.4959
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_log_S.pkl
#
#
#       ✓ gbm - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#   Target label: U
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_log_U.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4209, SRCC: 0.4457, KRCC: 0.3099, RMSE: 0.9844
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\by_component_log_U.pkl
#
#
#       ✓ svr - PLCC: 0.7976, SRCC: 0.7999, KRCC: 0.5999, RMSE: 0.4723
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None}
#
#
#       Model saved: ./random_forest\by_component_log_U.pkl
#
#
#       ✓ random_forest - PLCC: 0.7401, SRCC: 0.7312, KRCC: 0.5394, RMSE: 0.5288
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_log_U.pkl
#
#
#       ✓ gbm - PLCC: 0.7841, SRCC: 0.7902, KRCC: 0.5926, RMSE: 0.4898
#   Target label: O
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_log_O.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5499, SRCC: 0.5823, KRCC: 0.4156, RMSE: 1.2302
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\by_component_log_O.pkl
#
#
#       ✓ svr - PLCC: 0.8322, SRCC: 0.8293, KRCC: 0.6394, RMSE: 0.5989
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\by_component_log_O.pkl
#
#
#       ✓ random_forest - PLCC: 0.7851, SRCC: 0.7781, KRCC: 0.5879, RMSE: 0.6742
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_log_O.pkl
#
#
#       ✓ gbm - PLCC: 0.8286, SRCC: 0.8203, KRCC: 0.6318, RMSE: 0.6064
#
# Processing dataset: s_only_log
# Features loaded: s_only_log.csv, Shape: (1000, 1152)
#
#
#   Target label: TSV
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_log_TSV.pkl
#
#
#       ✓ linear_regression - PLCC: 0.6052, SRCC: 0.6182, KRCC: 0.4372, RMSE: 0.6982
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\s_only_log_TSV.pkl
#
#
#       ✓ svr - PLCC: 0.8394, SRCC: 0.8122, KRCC: 0.6274, RMSE: 0.3634
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
#
#
#       Model saved: ./random_forest\s_only_log_TSV.pkl
#
#
#       ✓ random_forest - PLCC: 0.7908, SRCC: 0.7597, KRCC: 0.5755, RMSE: 0.4061
#     Training gbm...
#       Best parameters: {'subsample': 0.8, 'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 5, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_log_TSV.pkl
#
#
#       ✓ gbm - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#   Target label: B
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_log_B.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4477, SRCC: 0.4640, KRCC: 0.3235, RMSE: 1.2661
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\s_only_log_B.pkl
#
#
#       ✓ svr - PLCC: 0.6928, SRCC: 0.6712, KRCC: 0.4901, RMSE: 0.5867
#     Training random_forest...
#       Best parameters: {'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
#
#
#       Model saved: ./random_forest\s_only_log_B.pkl
#
#
#       ✓ random_forest - PLCC: 0.6507, SRCC: 0.6033, KRCC: 0.4348, RMSE: 0.6223
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_log_B.pkl
#
#
#       ✓ gbm - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#   Target label: SR
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_log_SR.pkl
#
#
#       ✓ linear_regression - PLCC: 0.3131, SRCC: 0.3052, KRCC: 0.2058, RMSE: 1.0946
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\s_only_log_SR.pkl
#
#
#       ✓ svr - PLCC: 0.7042, SRCC: 0.7095, KRCC: 0.5207, RMSE: 0.4832
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\s_only_log_SR.pkl
#
#
#       ✓ random_forest - PLCC: 0.6372, SRCC: 0.6235, KRCC: 0.4476, RMSE: 0.5351
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_log_SR.pkl
#
#
#       ✓ gbm - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#   Target label: S
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_log_S.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5444, SRCC: 0.5716, KRCC: 0.4036, RMSE: 0.9133
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\s_only_log_S.pkl
#
#
#       ✓ svr - PLCC: 0.8197, SRCC: 0.8204, KRCC: 0.6202, RMSE: 0.4488
#     Training random_forest...
#       Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10}
#
#
#       Model saved: ./random_forest\s_only_log_S.pkl
#
#
#       ✓ random_forest - PLCC: 0.7742, SRCC: 0.7703, KRCC: 0.5687, RMSE: 0.4959
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_log_S.pkl
#
#
#       ✓ gbm - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#   Target label: U
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_log_U.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4518, SRCC: 0.4587, KRCC: 0.3170, RMSE: 0.9166
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\s_only_log_U.pkl
#
#
#       ✓ svr - PLCC: 0.7787, SRCC: 0.7805, KRCC: 0.5831, RMSE: 0.4906
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None}
#
#
#       Model saved: ./random_forest\s_only_log_U.pkl
#
#
#       ✓ random_forest - PLCC: 0.7399, SRCC: 0.7308, KRCC: 0.5393, RMSE: 0.5289
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_log_U.pkl
#
#
#       ✓ gbm - PLCC: 0.7841, SRCC: 0.7902, KRCC: 0.5926, RMSE: 0.4898
#   Target label: O
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_log_O.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5576, SRCC: 0.5819, KRCC: 0.4200, RMSE: 1.2079
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\s_only_log_O.pkl
#
#
#       ✓ svr - PLCC: 0.8189, SRCC: 0.8153, KRCC: 0.6244, RMSE: 0.6197
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\s_only_log_O.pkl
#
#
#       ✓ random_forest - PLCC: 0.7851, SRCC: 0.7780, KRCC: 0.5879, RMSE: 0.6741
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_log_O.pkl
#
#
#       ✓ gbm - PLCC: 0.8286, SRCC: 0.8203, KRCC: 0.6318, RMSE: 0.6064
#
# Processing dataset: all_features_log1p
# Features loaded: all_features_log1p.csv, Shape: (1000, 1152)
#
#
#   Target label: TSV
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_log1p_TSV.pkl
#
#
#       ✓ linear_regression - PLCC: 0.6204, SRCC: 0.6233, KRCC: 0.4460, RMSE: 0.6645
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\all_features_log1p_TSV.pkl
#
#
#       ✓ svr - PLCC: 0.8317, SRCC: 0.8028, KRCC: 0.6184, RMSE: 0.3724
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
#
#
#       Model saved: ./random_forest\all_features_log1p_TSV.pkl
#
#
#       ✓ random_forest - PLCC: 0.7908, SRCC: 0.7597, KRCC: 0.5756, RMSE: 0.4061
#     Training gbm...
#       Best parameters: {'subsample': 0.8, 'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 5, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_log1p_TSV.pkl
#
#
#       ✓ gbm - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#   Target label: B
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_log1p_B.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4399, SRCC: 0.4476, KRCC: 0.3131, RMSE: 1.2319
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\all_features_log1p_B.pkl
#
#
#       ✓ svr - PLCC: 0.6863, SRCC: 0.6625, KRCC: 0.4776, RMSE: 0.5913
#     Training random_forest...
#       Best parameters: {'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
#
#
#       Model saved: ./random_forest\all_features_log1p_B.pkl
#
#
#       ✓ random_forest - PLCC: 0.6507, SRCC: 0.6033, KRCC: 0.4348, RMSE: 0.6223
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_log1p_B.pkl
#
#
#       ✓ gbm - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#   Target label: SR
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_log1p_SR.pkl
#
#
#       ✓ linear_regression - PLCC: 0.3255, SRCC: 0.3255, KRCC: 0.2224, RMSE: 1.0816
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\all_features_log1p_SR.pkl
#
#
#       ✓ svr - PLCC: 0.6951, SRCC: 0.6943, KRCC: 0.5094, RMSE: 0.4900
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\all_features_log1p_SR.pkl
#
#
#       ✓ random_forest - PLCC: 0.6371, SRCC: 0.6236, KRCC: 0.4477, RMSE: 0.5351
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_log1p_SR.pkl
#
#
#       ✓ gbm - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#   Target label: S
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_log1p_S.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5289, SRCC: 0.5591, KRCC: 0.3968, RMSE: 0.9298
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\all_features_log1p_S.pkl
#
#
#       ✓ svr - PLCC: 0.8079, SRCC: 0.8044, KRCC: 0.6018, RMSE: 0.4621
#     Training random_forest...
#       Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10}
#
#
#       Model saved: ./random_forest\all_features_log1p_S.pkl
#
#
#       ✓ random_forest - PLCC: 0.7742, SRCC: 0.7701, KRCC: 0.5684, RMSE: 0.4959
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_log1p_S.pkl
#
#
#       ✓ gbm - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#   Target label: U
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_log1p_U.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4703, SRCC: 0.4641, KRCC: 0.3295, RMSE: 0.8737
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\all_features_log1p_U.pkl
#
#
#       ✓ svr - PLCC: 0.7745, SRCC: 0.7694, KRCC: 0.5739, RMSE: 0.4946
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None}
#
#
#       Model saved: ./random_forest\all_features_log1p_U.pkl
#
#
#       ✓ random_forest - PLCC: 0.7400, SRCC: 0.7309, KRCC: 0.5393, RMSE: 0.5288
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_log1p_U.pkl
#
#
#       ✓ gbm - PLCC: 0.7841, SRCC: 0.7902, KRCC: 0.5926, RMSE: 0.4898
#   Target label: O
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_log1p_O.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5479, SRCC: 0.5731, KRCC: 0.4173, RMSE: 1.1840
#     Training svr...
#       Best parameters: {'kernel': 'poly', 'gamma': 0.001, 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\all_features_log1p_O.pkl
#
#
#       ✓ svr - PLCC: 0.8150, SRCC: 0.8259, KRCC: 0.6336, RMSE: 0.6344
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\all_features_log1p_O.pkl
#
#
#       ✓ random_forest - PLCC: 0.7855, SRCC: 0.7783, KRCC: 0.5878, RMSE: 0.6736
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_log1p_O.pkl
#
#
#       ✓ gbm - PLCC: 0.8286, SRCC: 0.8203, KRCC: 0.6318, RMSE: 0.6064
#
# Processing dataset: by_component_log1p
# Features loaded: by_component_log1p.csv, Shape: (1000, 1152)
#
#
#   Target label: TSV
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_log1p_TSV.pkl
#
#
#       ✓ linear_regression - PLCC: 0.6218, SRCC: 0.6245, KRCC: 0.4475, RMSE: 0.6618
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\by_component_log1p_TSV.pkl
#
#
#       ✓ svr - PLCC: 0.8306, SRCC: 0.8009, KRCC: 0.6156, RMSE: 0.3736
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
#
#
#       Model saved: ./random_forest\by_component_log1p_TSV.pkl
#
#
#       ✓ random_forest - PLCC: 0.7908, SRCC: 0.7599, KRCC: 0.5758, RMSE: 0.4061
#     Training gbm...
#       Best parameters: {'subsample': 0.8, 'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 5, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_log1p_TSV.pkl
#
#
#       ✓ gbm - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#   Target label: B
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_log1p_B.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4419, SRCC: 0.4476, KRCC: 0.3123, RMSE: 1.2181
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\by_component_log1p_B.pkl
#
#
#       ✓ svr - PLCC: 0.6851, SRCC: 0.6605, KRCC: 0.4759, RMSE: 0.5921
#     Training random_forest...
#       Best parameters: {'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
#
#
#       Model saved: ./random_forest\by_component_log1p_B.pkl
#
#
#       ✓ random_forest - PLCC: 0.6507, SRCC: 0.6033, KRCC: 0.4348, RMSE: 0.6223
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_log1p_B.pkl
#
#
#       ✓ gbm - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#   Target label: SR
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_log1p_SR.pkl
#
#
#       ✓ linear_regression - PLCC: 0.3259, SRCC: 0.3251, KRCC: 0.2223, RMSE: 1.0797
#     Training svr...
#       Best parameters: {'kernel': 'poly', 'gamma': 0.001, 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\by_component_log1p_SR.pkl
#
#
#       ✓ svr - PLCC: 0.6839, SRCC: 0.6975, KRCC: 0.5031, RMSE: 0.5118
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\by_component_log1p_SR.pkl
#
#
#       ✓ random_forest - PLCC: 0.6371, SRCC: 0.6236, KRCC: 0.4477, RMSE: 0.5351
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_log1p_SR.pkl
#
#
#       ✓ gbm - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#   Target label: S
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_log1p_S.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5279, SRCC: 0.5554, KRCC: 0.3947, RMSE: 0.9276
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\by_component_log1p_S.pkl
#
#
#       ✓ svr - PLCC: 0.8061, SRCC: 0.8025, KRCC: 0.6001, RMSE: 0.4641
#     Training random_forest...
#       Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10}
#
#
#       Model saved: ./random_forest\by_component_log1p_S.pkl
#
#
#       ✓ random_forest - PLCC: 0.7742, SRCC: 0.7701, KRCC: 0.5684, RMSE: 0.4959
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_log1p_S.pkl
#
#
#       ✓ gbm - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#   Target label: U
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_log1p_U.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4752, SRCC: 0.4678, KRCC: 0.3291, RMSE: 0.8658
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\by_component_log1p_U.pkl
#
#
#       ✓ svr - PLCC: 0.7730, SRCC: 0.7671, KRCC: 0.5715, RMSE: 0.4960
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None}
#
#
#       Model saved: ./random_forest\by_component_log1p_U.pkl
#
#
#       ✓ random_forest - PLCC: 0.7401, SRCC: 0.7310, KRCC: 0.5394, RMSE: 0.5288
#     Training gbm...
#       Best parameters: {'subsample': 0.8, 'n_estimators': 50, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_depth': 7, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_log1p_U.pkl
#
#
#       ✓ gbm - PLCC: 0.7674, SRCC: 0.7692, KRCC: 0.5674, RMSE: 0.5040
#   Target label: O
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_log1p_O.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5492, SRCC: 0.5736, KRCC: 0.4172, RMSE: 1.1828
#     Training svr...
#       Best parameters: {'kernel': 'poly', 'gamma': 0.001, 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\by_component_log1p_O.pkl
#
#
#       ✓ svr - PLCC: 0.8169, SRCC: 0.8269, KRCC: 0.6356, RMSE: 0.6305
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\by_component_log1p_O.pkl
#
#
#       ✓ random_forest - PLCC: 0.7851, SRCC: 0.7781, KRCC: 0.5880, RMSE: 0.6741
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_log1p_O.pkl
#
#
#       ✓ gbm - PLCC: 0.8286, SRCC: 0.8203, KRCC: 0.6318, RMSE: 0.6064
#
# Processing dataset: s_only_log1p
# Features loaded: s_only_log1p.csv, Shape: (1000, 1152)
#
#
#   Target label: TSV
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_log1p_TSV.pkl
#
#
#       ✓ linear_regression - PLCC: 0.6130, SRCC: 0.6134, KRCC: 0.4395, RMSE: 0.6813
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\s_only_log1p_TSV.pkl
#
#
#       ✓ svr - PLCC: 0.8370, SRCC: 0.8131, KRCC: 0.6290, RMSE: 0.3663
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
#
#
#       Model saved: ./random_forest\s_only_log1p_TSV.pkl
#
#
#       ✓ random_forest - PLCC: 0.7908, SRCC: 0.7597, KRCC: 0.5756, RMSE: 0.4061
#     Training gbm...
#       Best parameters: {'subsample': 0.8, 'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 5, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_log1p_TSV.pkl
#
#
#       ✓ gbm - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#   Target label: B
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_log1p_B.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4322, SRCC: 0.4489, KRCC: 0.3129, RMSE: 1.2870
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\s_only_log1p_B.pkl
#
#
#       ✓ svr - PLCC: 0.6931, SRCC: 0.6774, KRCC: 0.4913, RMSE: 0.5858
#     Training random_forest...
#       Best parameters: {'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
#
#
#       Model saved: ./random_forest\s_only_log1p_B.pkl
#
#
#       ✓ random_forest - PLCC: 0.6507, SRCC: 0.6033, KRCC: 0.4348, RMSE: 0.6223
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_log1p_B.pkl
#
#
#       ✓ gbm - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#   Target label: SR
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_log1p_SR.pkl
#
#
#       ✓ linear_regression - PLCC: 0.3235, SRCC: 0.3224, KRCC: 0.2177, RMSE: 1.0852
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\s_only_log1p_SR.pkl
#
#
#       ✓ svr - PLCC: 0.7103, SRCC: 0.7153, KRCC: 0.5239, RMSE: 0.4798
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\s_only_log1p_SR.pkl
#
#
#       ✓ random_forest - PLCC: 0.6371, SRCC: 0.6235, KRCC: 0.4476, RMSE: 0.5351
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_log1p_SR.pkl
#
#
#       ✓ gbm - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#   Target label: S
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_log1p_S.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5278, SRCC: 0.5599, KRCC: 0.3980, RMSE: 0.9425
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\s_only_log1p_S.pkl
#
#
#       ✓ svr - PLCC: 0.8156, SRCC: 0.8129, KRCC: 0.6110, RMSE: 0.4537
#     Training random_forest...
#       Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10}
#
#
#       Model saved: ./random_forest\s_only_log1p_S.pkl
#
#
#       ✓ random_forest - PLCC: 0.7742, SRCC: 0.7703, KRCC: 0.5687, RMSE: 0.4959
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_log1p_S.pkl
#
#
#       ✓ gbm - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#   Target label: U
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_log1p_U.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4481, SRCC: 0.4424, KRCC: 0.3132, RMSE: 0.9128
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\s_only_log1p_U.pkl
#
#
#       ✓ svr - PLCC: 0.7789, SRCC: 0.7744, KRCC: 0.5797, RMSE: 0.4900
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None}
#
#
#       Model saved: ./random_forest\s_only_log1p_U.pkl
#
#
#       ✓ random_forest - PLCC: 0.7400, SRCC: 0.7306, KRCC: 0.5392, RMSE: 0.5288
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_log1p_U.pkl
#
#
#       ✓ gbm - PLCC: 0.7841, SRCC: 0.7902, KRCC: 0.5926, RMSE: 0.4898
#   Target label: O
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_log1p_O.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5403, SRCC: 0.5726, KRCC: 0.4148, RMSE: 1.2086
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\s_only_log1p_O.pkl
#
#
#       ✓ svr - PLCC: 0.8149, SRCC: 0.8107, KRCC: 0.6177, RMSE: 0.6264
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\s_only_log1p_O.pkl
#
#
#       ✓ random_forest - PLCC: 0.7851, SRCC: 0.7780, KRCC: 0.5879, RMSE: 0.6741
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_log1p_O.pkl
#
#
#       ✓ gbm - PLCC: 0.8286, SRCC: 0.8203, KRCC: 0.6318, RMSE: 0.6064
#
# Processing dataset: all_features_minmax
# Features loaded: all_features_minmax.csv, Shape: (1000, 1152)
#
#
#   Target label: TSV
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_minmax_TSV.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4671, SRCC: 0.4423, KRCC: 0.3081, RMSE: 1.0401
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\all_features_minmax_TSV.pkl
#
#
#       ✓ svr - PLCC: 0.8442, SRCC: 0.8221, KRCC: 0.6382, RMSE: 0.3657
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
#
#
#       Model saved: ./random_forest\all_features_minmax_TSV.pkl
#
#
#       ✓ random_forest - PLCC: 0.7909, SRCC: 0.7597, KRCC: 0.5756, RMSE: 0.4061
#     Training gbm...
#       Best parameters: {'subsample': 0.8, 'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 5, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_minmax_TSV.pkl
#
#
#       ✓ gbm - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#   Target label: B
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_minmax_B.pkl
#
#
#       ✓ linear_regression - PLCC: 0.3188, SRCC: 0.3364, KRCC: 0.2219, RMSE: 2.1373
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.01, 'C': 10}
#
#
#       Model saved: ./svr\all_features_minmax_B.pkl
#
#
#       ✓ svr - PLCC: 0.6974, SRCC: 0.6644, KRCC: 0.4809, RMSE: 0.5833
#     Training random_forest...
#       Best parameters: {'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 10}
#
#
#       Model saved: ./random_forest\all_features_minmax_B.pkl
#
#
#       ✓ random_forest - PLCC: 0.6529, SRCC: 0.6047, KRCC: 0.4376, RMSE: 0.6229
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_minmax_B.pkl
#
#
#       ✓ gbm - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#   Target label: SR
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_minmax_SR.pkl
#
#
#       ✓ linear_regression - PLCC: 0.0771, SRCC: 0.1249, KRCC: 0.0850, RMSE: 1.8820
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 0.1, 'epsilon': 0.1, 'C': 10}
#
#
#       Model saved: ./svr\all_features_minmax_SR.pkl
#
#
#       ✓ svr - PLCC: 0.7294, SRCC: 0.7273, KRCC: 0.5450, RMSE: 0.4720
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\all_features_minmax_SR.pkl
#
#
#       ✓ random_forest - PLCC: 0.6371, SRCC: 0.6236, KRCC: 0.4476, RMSE: 0.5351
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_minmax_SR.pkl
#
#
#       ✓ gbm - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#   Target label: S
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_minmax_S.pkl
#
#
#       ✓ linear_regression - PLCC: 0.3901, SRCC: 0.3871, KRCC: 0.2715, RMSE: 1.4403
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.01, 'C': 10}
#
#
#       Model saved: ./svr\all_features_minmax_S.pkl
#
#
#       ✓ svr - PLCC: 0.8281, SRCC: 0.8351, KRCC: 0.6328, RMSE: 0.4423
#     Training random_forest...
#       Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10}
#
#
#       Model saved: ./random_forest\all_features_minmax_S.pkl
#
#
#       ✓ random_forest - PLCC: 0.7742, SRCC: 0.7703, KRCC: 0.5686, RMSE: 0.4960
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_minmax_S.pkl
#
#
#       ✓ gbm - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#   Target label: U
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_minmax_U.pkl
#
#
#       ✓ linear_regression - PLCC: 0.2636, SRCC: 0.2927, KRCC: 0.2023, RMSE: 1.6085
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\all_features_minmax_U.pkl
#
#
#       ✓ svr - PLCC: 0.8178, SRCC: 0.8222, KRCC: 0.6285, RMSE: 0.4497
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None}
#
#
#       Model saved: ./random_forest\all_features_minmax_U.pkl
#
#
#       ✓ random_forest - PLCC: 0.7399, SRCC: 0.7305, KRCC: 0.5390, RMSE: 0.5289
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_minmax_U.pkl
#
#
#       ✓ gbm - PLCC: 0.7841, SRCC: 0.7902, KRCC: 0.5926, RMSE: 0.4898
#   Target label: O
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_minmax_O.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4317, SRCC: 0.4365, KRCC: 0.3053, RMSE: 1.7371
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\all_features_minmax_O.pkl
#
#
#       ✓ svr - PLCC: 0.8301, SRCC: 0.8308, KRCC: 0.6422, RMSE: 0.6050
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\all_features_minmax_O.pkl
#
#
#       ✓ random_forest - PLCC: 0.7851, SRCC: 0.7780, KRCC: 0.5879, RMSE: 0.6741
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_minmax_O.pkl
#
#
#       ✓ gbm - PLCC: 0.8286, SRCC: 0.8203, KRCC: 0.6318, RMSE: 0.6064
#
# Processing dataset: by_component_minmax
# Features loaded: by_component_minmax.csv, Shape: (1000, 1152)
#
#
#   Target label: TSV
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_minmax_TSV.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4671, SRCC: 0.4423, KRCC: 0.3081, RMSE: 1.0401
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\by_component_minmax_TSV.pkl
#
#
#       ✓ svr - PLCC: 0.8442, SRCC: 0.8221, KRCC: 0.6382, RMSE: 0.3657
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
#
#
#       Model saved: ./random_forest\by_component_minmax_TSV.pkl
#
#
#       ✓ random_forest - PLCC: 0.7909, SRCC: 0.7597, KRCC: 0.5756, RMSE: 0.4061
#     Training gbm...
#       Best parameters: {'subsample': 0.8, 'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 5, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_minmax_TSV.pkl
#
#
#       ✓ gbm - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#   Target label: B
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_minmax_B.pkl
#
#
#       ✓ linear_regression - PLCC: 0.3188, SRCC: 0.3364, KRCC: 0.2219, RMSE: 2.1373
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.01, 'C': 10}
#
#
#       Model saved: ./svr\by_component_minmax_B.pkl
#
#
#       ✓ svr - PLCC: 0.6974, SRCC: 0.6644, KRCC: 0.4809, RMSE: 0.5833
#     Training random_forest...
#       Best parameters: {'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 10}
#
#
#       Model saved: ./random_forest\by_component_minmax_B.pkl
#
#
#       ✓ random_forest - PLCC: 0.6529, SRCC: 0.6047, KRCC: 0.4376, RMSE: 0.6229
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_minmax_B.pkl
#
#
#       ✓ gbm - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#   Target label: SR
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_minmax_SR.pkl
#
#
#       ✓ linear_regression - PLCC: 0.0771, SRCC: 0.1249, KRCC: 0.0850, RMSE: 1.8820
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 0.1, 'epsilon': 0.1, 'C': 10}
#
#
#       Model saved: ./svr\by_component_minmax_SR.pkl
#
#
#       ✓ svr - PLCC: 0.7294, SRCC: 0.7273, KRCC: 0.5450, RMSE: 0.4720
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\by_component_minmax_SR.pkl
#
#
#       ✓ random_forest - PLCC: 0.6371, SRCC: 0.6236, KRCC: 0.4476, RMSE: 0.5351
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_minmax_SR.pkl
#
#
#       ✓ gbm - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#   Target label: S
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_minmax_S.pkl
#
#
#       ✓ linear_regression - PLCC: 0.3901, SRCC: 0.3871, KRCC: 0.2715, RMSE: 1.4403
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.01, 'C': 10}
#
#
#       Model saved: ./svr\by_component_minmax_S.pkl
#
#
#       ✓ svr - PLCC: 0.8281, SRCC: 0.8351, KRCC: 0.6328, RMSE: 0.4423
#     Training random_forest...
#       Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10}
#
#
#       Model saved: ./random_forest\by_component_minmax_S.pkl
#
#
#       ✓ random_forest - PLCC: 0.7742, SRCC: 0.7703, KRCC: 0.5686, RMSE: 0.4960
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_minmax_S.pkl
#
#
#       ✓ gbm - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#   Target label: U
# ...
#
#
#       Model saved: ./gbm\all_features_standard_S.pkl
#
#
#       ✓ gbm - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#   Target label: U
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_standard_U.pkl
#
#
#       ✓ linear_regression - PLCC: 0.2619, SRCC: 0.2864, KRCC: 0.1974, RMSE: 1.6558
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\all_features_standard_U.pkl
#
#
#       ✓ svr - PLCC: 0.8510, SRCC: 0.8504, KRCC: 0.6552, RMSE: 0.4230
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None}
#
#
#       Model saved: ./random_forest\all_features_standard_U.pkl
#
#
#       ✓ random_forest - PLCC: 0.7399, SRCC: 0.7305, KRCC: 0.5390, RMSE: 0.5289
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_standard_U.pkl
#
#
#       ✓ gbm - PLCC: 0.7841, SRCC: 0.7902, KRCC: 0.5926, RMSE: 0.4898
#   Target label: O
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\all_features_standard_O.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4323, SRCC: 0.4302, KRCC: 0.3009, RMSE: 1.7924
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.01, 'C': 10}
#
#
#       Model saved: ./svr\all_features_standard_O.pkl
#
#
#       ✓ svr - PLCC: 0.8705, SRCC: 0.8675, KRCC: 0.6807, RMSE: 0.5350
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\all_features_standard_O.pkl
#
#
#       ✓ random_forest - PLCC: 0.7851, SRCC: 0.7778, KRCC: 0.5877, RMSE: 0.6741
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\all_features_standard_O.pkl
#
#
#       ✓ gbm - PLCC: 0.8286, SRCC: 0.8203, KRCC: 0.6318, RMSE: 0.6064
#
# Processing dataset: by_component_standard
# Features loaded: by_component_standard.csv, Shape: (1000, 1152)
#
#
#   Target label: TSV
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_standard_TSV.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4574, SRCC: 0.4352, KRCC: 0.3003, RMSE: 1.0805
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.01, 'C': 10}
#
#
#       Model saved: ./svr\by_component_standard_TSV.pkl
#
#
#       ✓ svr - PLCC: 0.8764, SRCC: 0.8535, KRCC: 0.6696, RMSE: 0.3195
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
#
#
#       Model saved: ./random_forest\by_component_standard_TSV.pkl
#
#
#       ✓ random_forest - PLCC: 0.7909, SRCC: 0.7597, KRCC: 0.5756, RMSE: 0.4061
#     Training gbm...
#       Best parameters: {'subsample': 0.8, 'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 5, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_standard_TSV.pkl
#
#
#       ✓ gbm - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#   Target label: B
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_standard_B.pkl
#
#
#       ✓ linear_regression - PLCC: 0.3096, SRCC: 0.3274, KRCC: 0.2168, RMSE: 2.2437
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\by_component_standard_B.pkl
#
#
#       ✓ svr - PLCC: 0.7355, SRCC: 0.7144, KRCC: 0.5237, RMSE: 0.5550
#     Training random_forest...
#       Best parameters: {'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 10}
#
#
#       Model saved: ./random_forest\by_component_standard_B.pkl
#
#
#       ✓ random_forest - PLCC: 0.6529, SRCC: 0.6047, KRCC: 0.4376, RMSE: 0.6229
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_standard_B.pkl
#
#
#       ✓ gbm - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#   Target label: SR
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_standard_SR.pkl
#
#
#       ✓ linear_regression - PLCC: 0.0626, SRCC: 0.0998, KRCC: 0.0687, RMSE: 1.9690
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\by_component_standard_SR.pkl
#
#
#       ✓ svr - PLCC: 0.7463, SRCC: 0.7497, KRCC: 0.5629, RMSE: 0.4529
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\by_component_standard_SR.pkl
#
#
#       ✓ random_forest - PLCC: 0.6370, SRCC: 0.6236, KRCC: 0.4477, RMSE: 0.5352
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_standard_SR.pkl
#
#
#       ✓ gbm - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#   Target label: S
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_standard_S.pkl
#
#
#       ✓ linear_regression - PLCC: 0.3780, SRCC: 0.3699, KRCC: 0.2567, RMSE: 1.5228
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.01, 'C': 10}
#
#
#       Model saved: ./svr\by_component_standard_S.pkl
#
#
#       ✓ svr - PLCC: 0.8776, SRCC: 0.8709, KRCC: 0.6824, RMSE: 0.3780
#     Training random_forest...
#       Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10}
#
#
#       Model saved: ./random_forest\by_component_standard_S.pkl
#
#
#       ✓ random_forest - PLCC: 0.7742, SRCC: 0.7703, KRCC: 0.5686, RMSE: 0.4960
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_standard_S.pkl
#
#
#       ✓ gbm - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#   Target label: U
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_standard_U.pkl
#
#
#       ✓ linear_regression - PLCC: 0.2619, SRCC: 0.2864, KRCC: 0.1974, RMSE: 1.6558
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\by_component_standard_U.pkl
#
#
#       ✓ svr - PLCC: 0.8510, SRCC: 0.8504, KRCC: 0.6552, RMSE: 0.4230
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None}
#
#
#       Model saved: ./random_forest\by_component_standard_U.pkl
#
#
#       ✓ random_forest - PLCC: 0.7399, SRCC: 0.7305, KRCC: 0.5390, RMSE: 0.5289
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_standard_U.pkl
#
#
#       ✓ gbm - PLCC: 0.7841, SRCC: 0.7902, KRCC: 0.5926, RMSE: 0.4898
#   Target label: O
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\by_component_standard_O.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4323, SRCC: 0.4302, KRCC: 0.3009, RMSE: 1.7924
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.01, 'C': 10}
#
#
#       Model saved: ./svr\by_component_standard_O.pkl
#
#
#       ✓ svr - PLCC: 0.8705, SRCC: 0.8675, KRCC: 0.6807, RMSE: 0.5350
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\by_component_standard_O.pkl
#
#
#       ✓ random_forest - PLCC: 0.7851, SRCC: 0.7778, KRCC: 0.5877, RMSE: 0.6741
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\by_component_standard_O.pkl
#
#
#       ✓ gbm - PLCC: 0.8286, SRCC: 0.8203, KRCC: 0.6318, RMSE: 0.6064
#
# Processing dataset: s_only_standard
# Features loaded: s_only_standard.csv, Shape: (1000, 1152)
#
#
#   Target label: TSV
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_standard_TSV.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5869, SRCC: 0.6248, KRCC: 0.4463, RMSE: 0.7320
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.01, 'C': 10}
#
#
#       Model saved: ./svr\s_only_standard_TSV.pkl
#
#
#       ✓ svr - PLCC: 0.8228, SRCC: 0.7788, KRCC: 0.5958, RMSE: 0.3821
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 30}
#
#
#       Model saved: ./random_forest\s_only_standard_TSV.pkl
#
#
#       ✓ random_forest - PLCC: 0.7909, SRCC: 0.7597, KRCC: 0.5756, RMSE: 0.4061
#     Training gbm...
#       Best parameters: {'subsample': 0.8, 'n_estimators': 50, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 5, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_standard_TSV.pkl
#
#
#       ✓ gbm - PLCC: 0.8233, SRCC: 0.7920, KRCC: 0.6070, RMSE: 0.3771
#   Target label: B
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_standard_B.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4510, SRCC: 0.4205, KRCC: 0.2872, RMSE: 1.2736
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.01, 'C': 10}
#
#
#       Model saved: ./svr\s_only_standard_B.pkl
#
#
#       ✓ svr - PLCC: 0.7004, SRCC: 0.6628, KRCC: 0.4840, RMSE: 0.5841
#     Training random_forest...
#       Best parameters: {'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 10}
#
#
#       Model saved: ./random_forest\s_only_standard_B.pkl
#
#
#       ✓ random_forest - PLCC: 0.6529, SRCC: 0.6047, KRCC: 0.4376, RMSE: 0.6230
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_standard_B.pkl
#
#
#       ✓ gbm - PLCC: 0.7175, SRCC: 0.6670, KRCC: 0.4943, RMSE: 0.5689
#   Target label: SR
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_standard_SR.pkl
#
#
#       ✓ linear_regression - PLCC: 0.3284, SRCC: 0.3519, KRCC: 0.2413, RMSE: 1.1737
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\s_only_standard_SR.pkl
#
#
#       ✓ svr - PLCC: 0.7000, SRCC: 0.6995, KRCC: 0.5119, RMSE: 0.4935
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\s_only_standard_SR.pkl
#
#
#       ✓ random_forest - PLCC: 0.6370, SRCC: 0.6236, KRCC: 0.4477, RMSE: 0.5352
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_standard_SR.pkl
#
#
#       ✓ gbm - PLCC: 0.6744, SRCC: 0.6403, KRCC: 0.4588, RMSE: 0.5039
#   Target label: S
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_standard_S.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5041, SRCC: 0.5339, KRCC: 0.3792, RMSE: 1.0325
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\s_only_standard_S.pkl
#
#
#       ✓ svr - PLCC: 0.8220, SRCC: 0.8245, KRCC: 0.6345, RMSE: 0.4539
#     Training random_forest...
#       Best parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10}
#
#
#       Model saved: ./random_forest\s_only_standard_S.pkl
#
#
#       ✓ random_forest - PLCC: 0.7742, SRCC: 0.7703, KRCC: 0.5686, RMSE: 0.4960
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_standard_S.pkl
#
#
#       ✓ gbm - PLCC: 0.7951, SRCC: 0.7924, KRCC: 0.5927, RMSE: 0.4753
#   Target label: U
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_standard_U.pkl
#
#
#       ✓ linear_regression - PLCC: 0.4218, SRCC: 0.4428, KRCC: 0.3155, RMSE: 1.0046
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\s_only_standard_U.pkl
#
#
#       ✓ svr - PLCC: 0.8100, SRCC: 0.8075, KRCC: 0.6106, RMSE: 0.4576
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None}
#
#
#       Model saved: ./random_forest\s_only_standard_U.pkl
#
#
#       ✓ random_forest - PLCC: 0.7399, SRCC: 0.7305, KRCC: 0.5390, RMSE: 0.5289
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_standard_U.pkl
#
#
#       ✓ gbm - PLCC: 0.7841, SRCC: 0.7902, KRCC: 0.5926, RMSE: 0.4898
#   Target label: O
#     Training linear_regression...
#
#
#       Model saved: ./linear_regression\s_only_standard_O.pkl
#
#
#       ✓ linear_regression - PLCC: 0.5085, SRCC: 0.5626, KRCC: 0.4039, RMSE: 1.3379
#     Training svr...
#       Best parameters: {'kernel': 'rbf', 'gamma': 'auto', 'epsilon': 0.2, 'C': 100}
#
#
#       Model saved: ./svr\s_only_standard_O.pkl
#
#
#       ✓ svr - PLCC: 0.8369, SRCC: 0.8343, KRCC: 0.6468, RMSE: 0.5928
#     Training random_forest...
#       Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20}
#
#
#       Model saved: ./random_forest\s_only_standard_O.pkl
#
#
#       ✓ random_forest - PLCC: 0.7851, SRCC: 0.7780, KRCC: 0.5879, RMSE: 0.6741
#     Training gbm...
#       Best parameters: {'subsample': 1.0, 'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 3, 'learning_rate': 0.1}
#
#
#       Model saved: ./gbm\s_only_standard_O.pkl
#
#
#       ✓ gbm - PLCC: 0.8286, SRCC: 0.8203, KRCC: 0.6318, RMSE: 0.6064
#
# Training completed!
# Successfully trained: 504/504 models
#
#
#
# Results saved to: ./training_results.csv
#
# ================================================================================
# TRAINING RESULTS SUMMARY
# ================================================================================
#
# Best PLCC:
#   svr on all_features_power for S: 0.8854
#
# Best SRCC:
#   svr on all_features_power for S: 0.8792
#
# Best KRCC:
#   svr on all_features_power for S: 0.6931
#
# Best RMSE:
#   svr on all_features_power for TSV: 0.3158
#
# Average Performance by Model:
#   gbm:
#     PLCC: 0.7704
#     SRCC: 0.7503
#     KRCC: 0.5628
#     RMSE: 0.5036
#   linear_regression:
#     PLCC: 0.4062
#     SRCC: 0.4251
#     KRCC: 0.2972
#     RMSE: 1.3711
#   random_forest:
#     PLCC: 0.7298
#     SRCC: 0.7110
#     KRCC: 0.5257
#     RMSE: 0.5438
#   svr:
#     PLCC: 0.7972
#     SRCC: 0.7889
#     KRCC: 0.5996
#     RMSE: 0.4760
#
# Top 5 Dataset Configurations (by PLCC):
#   s_only_power → TSV: 0.7688
#   by_component_log1p → TSV: 0.7666
#   all_features_log1p → TSV: 0.7666
#   s_only_log1p → TSV: 0.7660
#   s_only_log → TSV: 0.7647
#
#
#
#
#
# All models have been trained and saved!
